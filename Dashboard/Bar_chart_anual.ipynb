# %%
import numpy as np
import pandas as pd
from math import pi
import pandas as pd

# %% [markdown]
# # Alertas anuales

# %%
data = pd.read_csv('C:/Users/Ceiec04/Desktop/Prediccion_Alertas_Alimentarias/Datasets/full_RASFF_DATA_20072020.csv', sep=';', 
                   header=0, index_col = 0)

# %%
data['DATE_CASE'] =pd.to_datetime(data.DATE_CASE)
datag = data.groupby(data.DATE_CASE.dt.year).size()

# %%
chart = data.groupby(data.DATE_CASE.dt.year).size().plot.bar(figsize= (10,5))
chart

# %%
fig = chart.get_figure()
fig.savefig('barras_alertas_20072020.png')

# %% [markdown]
# # 2019 por meses

# %%
data = pd.read_csv('C:/Users/Ceiec04/Desktop/Prediccion_Alertas_Alimentarias/Datasets/2019_ALERTS.csv', sep=';', 
                   header=0, index_col = 0)

# %%
data['DATE_CASE'] =pd.to_datetime(data.DATE_CASE)

# %%
chart = data.groupby(data.DATE_CASE.dt.month).size().plot.bar(figsize= (10,5))
