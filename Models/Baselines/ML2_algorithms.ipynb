# %% [markdown]
# # Librerias

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn import tree
from sklearn.metrics import classification_report

# %% [markdown]
# # Datos entrenamiento

# %%
data = pd.read_csv('C:/Users/Ceiec04/Desktop/Prediccion_Alertas_Alimentarias/Datasets/RASFF_DATA_16092019.csv', sep=';', 
                   header=0, index_col = 0)
df = data
df
# Out:
#         NUMBER                    CLASSIF   DATE_CASE        REF  \
# 0          1.0                      alert  2019-09-13  2019.3276
# 1          3.0                      alert  2019-09-13  2019.3262
# 2          5.0  information for attention  2019-09-13  2019.3271
# 3          7.0                      alert  2019-09-13  2019.3269
# 4          9.0           border rejection  2019-09-13  2019.3267
# 5         11.0           border rejection  2019-09-13  2019.3266
# 6         13.0  information for attention  2019-09-13  2019.3264
# 7         15.0           border rejection  2019-09-13  2019.3259
# 8         17.0           border rejection  2019-09-12  2019.3251
# 9         19.0           border rejection  2019-09-12  2019.3254
# 10        21.0  information for follow-up  2019-09-12  2019.3255
# 11        23.0  information for attention  2019-09-12  2019.3247
# 12        25.0                      alert  2019-09-12  2019.3243
# 13        27.0  information for follow-up  2019-09-12  2019.3249
# 14        29.0  information for follow-up  2019-09-12  2019.3245
# 15        31.0                      alert  2019-09-12  2019.3242
# 16        33.0                      alert  2019-09-11  2019.3236
# 17        35.0                      alert  2019-09-11  2019.3240
# 18        37.0                      alert  2019-09-11  2019.3229
# 19        39.0  information for attention  2019-09-11  2019.3234
# 20        41.0                      alert  2019-09-11  2019.3231
# 21        43.0                      alert  2019-09-10  2019.3221
# 22        45.0                      alert  2019-09-10  2019.3225
# 23        47.0           border rejection  2019-09-10  2019.3222
# 24        49.0  information for attention  2019-09-10  2019.3210
# 25        51.0  information for attention  2019-09-10  2019.3215
# 26        53.0           border rejection  2019-09-10  2019.3227
# 27        55.0  information for attention  2019-09-10  2019.3220
# 28        57.0           border rejection  2019-09-10  2019.3224
# 29        59.0  information for follow-up  2019-09-10  2019.3218
# ...        ...                        ...         ...        ...
# 50481  50464.0                information  2004-01-12   2004.ABD
# 50482  50466.0                information  2004-01-12   2004.ABB
# 50483  50468.0                      alert  2004-01-12   2004.019
# 50484  50470.0                      alert  2004-01-12   2004.017
# 50485  50472.0                information  2004-01-09   2004.AAZ
# 50486  50474.0                information  2004-01-09   2004.AAX
# 50487  50476.0                information  2004-01-09   2004.AAV
# 50488  50478.0                information  2004-01-09   2004.AAT
# 50489  50480.0                      alert  2004-01-09   2004.013
# 50490  50482.0                      alert  2004-01-09   2004.008
# 50491  50484.0                      alert  2004-01-08   2004.011
# 50492  50486.0                information  2004-01-08   2004.AAQ
# 50493  50488.0                      alert  2004-01-08   2004.010
# 50494  50490.0                information  2004-01-07   2004.AAK
# 50495  50492.0                information  2004-01-07   2004.AAJ
# 50496  50494.0                information  2004-01-07   2004.AAI
# 50497  50496.0                information  2004-01-07   2004.AAN
# 50498  50498.0                      alert  2004-01-07   2004.007
# 50499  50500.0                information  2004-01-06   2004.AAG
# 50500  50501.0                information  2004-01-06   2004.AAF
# 50501  50503.0                      alert  2004-01-06   2004.005
# 50502  50505.0                      alert  2004-01-06   2004.003
# 50503  50507.0                information  2004-01-05   2004.AAD
# 50504  50509.0                information  2004-01-05   2004.AAA
# 50505  50511.0                      alert  2004-01-05   2004.001
# 50550  50502.0                information  2004-01-06   2004.AAE
# 50551  50504.0                      alert  2004-01-06   2004.004
# 50552  50506.0                information  2004-01-05   2004.AAB
# 50553  50508.0                information  2004-01-05   2004.AAC
# 50554  50510.0                      alert  2004-01-05   2004.002
#
#           NOT_COUNTRY                                             SUBJET  \
# 0              France  foodborne outbreak suspected (Salmonella enter...
# 1             Denmark  pyrrolizidine alkaloids (903 µg/kg - ppb) in n...
# 2              Poland  sulphite (50 mg/kg - ppm) undeclared on biscui...
# 3               Spain  arsenic (0.38; 0.29; 0.31 mg/kg - ppm) in full...
# 4              France  ochratoxin A (30 µg/kg - ppb) in raisins from ...
# 5              Poland  Salmonella group E4 (presence /25g) in rapesee...
# 6             Denmark  foodborne outbreak suspected to be caused by a...
# 7         Netherlands  mercury (1.8 mg/kg - ppm) in frozen marlin loi...
# 8             Germany  aflatoxins (B1 = 0.049 mg/kg - ppm) in groundn...
# 9            Bulgaria  formetanate (0.096 mg/kg - ppm) in peppers fro...
# 10            Finland  Salmonella enterica ser. Mbandaka (presence /2...
# 11             Poland  Salmonella (presence /25g) in chilled poultry ...
# 12        Netherlands  polycyclic aromatic hydrocarbons (1110 µg/kg -...
# 13        Netherlands  suspicion of dioxins (1.25 WHO PCDD/F-TEQ/kg) ...
# 14            Finland  Salmonella enterica ser. Kottbus (presence /25...
# 15              Italy  too high count of Escherichia coli (up to 1600...
# 16            Denmark  pyrrolizidine alkaloids (793 µg/kg - ppb) in h...
# 17            Belgium  arsenic (30.7 mg/kg - ppm) in food supplement ...
# 18            Belgium  incorrect labelling (allergens not labelled in...
# 19             Poland  Listeria monocytogenes (presence /25g) in chee...
# 20        Netherlands  Listeria monocytogenes (>1500 CFU/g) in black ...
# 21             Sweden  high content of Senna alexandrina Mill. in sen...
# 22              Italy  unauthorised substance nortadalafil (107 mg/g)...
# 23     United Kingdom  aflatoxins (B1 = 4.2; Tot. = 5 µg/kg - ppb) in...
# 24        Netherlands  aflatoxins (B1 = 52.6; Tot. = 55.3 µg/kg - ppb...
# 25        Netherlands  aflatoxins (B1 = 12 µg/kg - ppb) in organic ch...
# 26             Poland  missing import declaration for plastic thermos...
# 27             Norway  migration of melamine (3.33 mg/kg - ppm) from ...
# 28              Italy  unauthorised use of colour E 102 - tartrazine ...
# 29            Germany  unauthorised novel food ingredient cannabidiol...
# ...               ...                                                ...
# 50481           Italy                  aflatoxins in pistachios in shell
# 50482          Sweden          Salmonella Mbandaka (positive) in Soypass
# 50483         Austria  unauthorised colour Sudan 1 (0.48; 0.64 mg/kg ...
# 50484         Finland  Salmonella Agona (1 out of 2 positive /25g) in...
# 50485           Spain  fenvalerate (0.45 mg/kg - ppm) and unauthorise...
# 50486           Italy  Vibrio parahaemolyticus (presence) in frozen s...
# 50487           Spain  arsenic (0.2 mg/kg - ppm) and lead (0.3 mg/kg ...
# 50488           Spain  too high content of E 210 - benzoic acid (344 ...
# 50489         Germany  unauthorised colour Sudan 1 (6 mg/kg - ppm) in...
# 50490           Italy  unauthorised colour Sudan 1 (0.51 mg/kg - ppm)...
# 50491  United Kingdom  prohibited substance nitrofuran (metabolite) n...
# 50492         Germany     BSE tests not conducted on slaughtered bovines
# 50493           Italy  unauthorised colour Sudan 1 (presence) in chil...
# 50494           Italy  Salmonella enterica (presence /25g) in frozen ...
# 50495         Germany    spoilage of frozen sea water shrimps from India
# 50496          France  Salmonella (presence in 3/5) and too high coun...
# 50497  United Kingdom  streptomycin (120 µg/kg - ppb) unauthorised in...
# 50498         Finland  Salmonella enteritidis (1 out of 2 samples /25...
# 50499           Spain             cadmium (0.1 mg/kg - ppm) in swordfish
# 50500         Germany  unauthorised establishment for ice cream assor...
# 50501           Italy  E 452 - polyphosphates (3550; 2700; 750; 3430 ...
# 50502           Italy  Salmonella (presence /25g) in frozen pig diaph...
# 50503         Germany  dioxins (2.147 pg WHO/g) in sugar yeast cultur...
# 50504           Italy  too high content of E 200 - sorbic acid (3616 ...
# 50505          France   Listeria monocytogenes (presence) in frozen deer
# 50550           Spain  too high content of E 210 - benzoic acid (178 ...
# 50551           Italy  E 452 - polyphosphates (520; 2340; 1820; 640 m...
# 50552           Italy  incorrect labelling (labelling absent or missi...
# 50553        Portugal  Salmonella baguida (presence /25g) in frozen o...
# 50554     Netherlands  histamine in fresh chilled yellowfin tuna loin...
#
#                                                 PROD_CAT  TYPE RISK_DECISION  \
# 0            meat and meat products (other than poultry)  food       serious
# 1           cocoa and cocoa preparations, coffee and tea  food       serious
# 2                                          confectionery  food       serious
# 3                            cereals and bakery products  food       serious
# 4                                  fruits and vegetables  food       serious
# 5                                         feed materials  feed   not serious
# 6                  bivalve molluscs and products thereof  food       serious
# 7                                 fish and fish products  food       serious
# 8                                         feed materials  feed       serious
# 9                                  fruits and vegetables  food       serious
# 10                                        feed materials  feed   not serious
# 11                poultry meat and poultry meat products  food   not serious
# 12     dietetic foods, food supplements, fortified foods  food       serious
# 13                                        feed materials  feed     undecided
# 14                                        feed materials  feed   not serious
# 15                 bivalve molluscs and products thereof  food       serious
# 16          cocoa and cocoa preparations, coffee and tea  food       serious
# 17     dietetic foods, food supplements, fortified foods  food       serious
# 18                            prepared dishes and snacks  food       serious
# 19                                milk and milk products  food       serious
# 20                                 fruits and vegetables  food       serious
# 21          cocoa and cocoa preparations, coffee and tea  food       serious
# 22     dietetic foods, food supplements, fortified foods  food       serious
# 23                          nuts, nut products and seeds  food       serious
# 24                                      herbs and spices  food       serious
# 25                                      herbs and spices  food       serious
# 26                                food contact materials   fcm     undecided
# 27                                food contact materials   fcm     undecided
# 28                            prepared dishes and snacks  food   not serious
# 29     dietetic foods, food supplements, fortified foods  food     undecided
# ...                                                  ...   ...           ...
# 50481                       nuts, nut products and seeds  food     undecided
# 50482                      animal nutrition - (obsolete)  feed     undecided
# 50483               soups, broths, sauces and condiments  food     undecided
# 50484             poultry meat and poultry meat products  food     undecided
# 50485       cocoa and cocoa preparations, coffee and tea  food     undecided
# 50486                   crustaceans and products thereof  food     undecided
# 50487                                      confectionery  food     undecided
# 50488                            non-alcoholic beverages  food     undecided
# 50489               soups, broths, sauces and condiments  food     undecided
# 50490                             fish and fish products  food     undecided
# 50491                   crustaceans and products thereof  food     undecided
# 50492        meat and meat products (other than poultry)  food     undecided
# 50493               soups, broths, sauces and condiments  food     undecided
# 50494                             fish and fish products  food     undecided
# 50495                   crustaceans and products thereof  food     undecided
# 50496                   crustaceans and products thereof  food     undecided
# 50497                              honey and royal jelly  food     undecided
# 50498             poultry meat and poultry meat products  food     undecided
# 50499                             fish and fish products  food     undecided
# 50500                                  ices and desserts  food     undecided
# 50501                             fish and fish products  food     undecided
# 50502        meat and meat products (other than poultry)  food     undecided
# 50503                      animal nutrition - (obsolete)  feed     undecided
# 50504                        cereals and bakery products  food     undecided
# 50505        meat and meat products (other than poultry)  food     undecided
# 50550                            non-alcoholic beverages  food     undecided
# 50551                             fish and fish products  food     undecided
# 50552                              fruits and vegetables  food     undecided
# 50553         molluscs and products thereof - (obsolete)  food     undecided
# 50554                             fish and fish products  food     undecided
#
#                                ACTION_TAKEN  \
# 0                             no stock left
# 1                     recall from consumers
# 2                     informing authorities
# 3                withdrawal from the market
# 4                               re-dispatch
# 5                    informing recipient(s)
# 6              withdrawal from recipient(s)
# 7                     import not authorised
# 8                               re-dispatch
# 9                               destruction
# 10              physical/chemical treatment
# 11                   informing recipient(s)
# 12                      informing consignor
# 13                              destruction
# 14              physical/chemical treatment
# 15               withdrawal from the market
# 16                    recall from consumers
# 17                    recall from consumers
# 18                    recall from consumers
# 19               withdrawal from the market
# 20                   informing recipient(s)
# 21
# 22                                  seizure
# 23     use for other purpose than food/feed
# 24                    informing authorities
# 25                    informing authorities
# 26                              re-dispatch
# 27                    recall from consumers
# 28               placed under customs seals
# 29               withdrawal from the market
# ...                                     ...
# 50481                           re-dispatch
# 50482           physical/chemical treatment
# 50483                            (obsolete)
# 50484                   return to consignor
# 50485                           destruction
# 50486                           destruction
# 50487                           destruction
# 50488                           destruction
# 50489                            (obsolete)
# 50490
# 50491
# 50492
# 50493                            (obsolete)
# 50494                           re-dispatch
# 50495                           destruction
# 50496                           destruction
# 50497                           re-dispatch
# 50498                   return to consignor
# 50499                           destruction
# 50500                           destruction
# 50501                   return to consignor
# 50502                   return to consignor
# 50503                               seizure
# 50504                           re-dispatch
# 50505                            (obsolete)
# 50550                           destruction
# 50551
# 50552
# 50553
# 50554
#
#                                      DISTRIBUTION_STAT  \
# 0               no distribution from notifying country
# 1               no distribution from notifying country
# 2         distribution restricted to notifying country
# 3                 distribution to non-member countries
# 4               product not (yet) placed on the market
# 5               product not (yet) placed on the market
# 6         product (presumably) no longer on the market
# 7               product not (yet) placed on the market
# 8               product not (yet) placed on the market
# 9               product not (yet) placed on the market
# 10              no distribution from notifying country
# 11        product (presumably) no longer on the market
# 12              no distribution from notifying country
# 13              no distribution from notifying country
# 14              no distribution from notifying country
# 15              distribution to other member countries
# 16              distribution to other member countries
# 17                               product traded online
# 18              distribution to other member countries
# 19                distribution to non-member countries
# 20              no distribution from notifying country
# 21              distribution to other member countries
# 22     information on distribution not (yet) available
# 23              product not (yet) placed on the market
# 24        product (presumably) no longer on the market
# 25        product (presumably) no longer on the market
# 26              product not (yet) placed on the market
# 27        distribution restricted to notifying country
# 28              product not (yet) placed on the market
# 29              distribution to other member countries
# ...                                                ...
# 50481
# 50482
# 50483
# 50484
# 50485
# 50486
# 50487
# 50488
# 50489
# 50490
# 50491
# 50492
# 50493
# 50494
# 50495
# 50496
# 50497
# 50498
# 50499
# 50500
# 50501
# 50502
# 50503
# 50504
# 50505
# 50550
# 50551
# 50552
# 50553
# 50554
#
#                                                  PRODUCT  \
# 0                          chilled raw minced horse meat
# 1                                             nettle tea
# 2                                               biscuits
# 3                                        full brown rice
# 4                                                raisins
# 5                                          rapeseed meal
# 6                       live oysters (crassostrea gigas)
# 7                          frozen marlin loin and steaks
# 8                               groundnuts for wildbirds
# 9                                                peppers
# 10                                    rape seed expeller
# 11                                  chilled poultry meat
# 12                                      chlorella powder
# 13                                             silkworms
# 14                                         rapeseed meal
# 15                         live clams (chamelea gallina)
# 16                                            herbal tea
# 17                                       food supplement
# 18                                       chilled lasagne
# 19                                                cheese
# 20                                     black olive rings
# 21                                      senna herbal tea
# 22                                       food supplement
# 23                                   groundnuts in shell
# 24                                organic chilli peppers
# 25                                organic chilli peppers
# 26                                       plastic thermos
# 27                                           bamboo cups
# 28                                               noodles
# 29                                              cbd oils
# ...                                                  ...
# 50481                                pistachios in shell
# 50482                                            soypass
# 50483                      spicy sauce "sugo arrabbiata"
# 50484                         raw frozen chicken breasts
# 50485                                          green tea
# 50486                 frozen shellfish (penaeus indicus)
# 50487                                        chewing gum
# 50488                              flavoured soft drinks
# 50489                     "arrabiata" spicy tomato sauce
# 50490                      preserved anchovies in chilli
# 50491  frozen headless shell-on fresh water shrimps (...
# 50492                                slaughtered bovines
# 50493                                      chilli sauces
# 50494   frozen catfish fillets (pangasius hypophthalmus)
# 50495                           frozen sea water shrimps
# 50496                                     frozen shrimps
# 50497                  bulk honey for further processing
# 50498                  raw frozen chicken breast fillets
# 50499                                          swordfish
# 50500                               ice cream assortment
# 50501  squid, red gurnard, smoothhound shark and cutt...
# 50502                               frozen pig diaphragm
# 50503                   sugar yeast cultured on molasses
# 50504                                       pasta sheets
# 50505                                        frozen deer
# 50550                                  soft fizzy drinks
# 50551  cuttlefish, red gurnard, squid and tope shark ...
# 50552  canned shoots, canned dried black fungus + dri...
# 50553                                     frozen octopus
# 50554  fresh chilled yellowfin tuna loins (thunnus al...
#
#                                                  HAZARDS  \
# 0                           foodborne outbreak suspected
# 1                                pyrrolizidine alkaloids
# 2                                    sulphite undeclared
# 3                                                arsenic
# 4                                           ochratoxin a
# 5                                    salmonella group e4
# 6                 foodborne outbreak suspected,norovirus
# 7                                                mercury
# 8                                             aflatoxins
# 9                                            formetanate
# 10                     salmonella enterica ser. mbandaka
# 11                                            salmonella
# 12                      polycyclic aromatic hydrocarbons
# 13                                  suspicion of dioxins
# 14                      salmonella enterica ser. kottbus
# 15                    too high count of escherichia coli
# 16                               pyrrolizidine alkaloids
# 17                                               arsenic
# 18                                   incorrect labelling
# 19                                listeria monocytogenes
# 20                                listeria monocytogenes
# 21               high content of senna alexandrina mill.
# 22     incorrect labelling,unauthorised substance nor...
# 23                                            aflatoxins
# 24                                            aflatoxins
# 25                                            aflatoxins
# 26                            missing import declaration
# 27                                 migration of melamine
# 28         unauthorised use of colour e 102 - tartrazine
# 29     unauthorised novel food ingredient cannabidiol...
# ...                                                  ...
# 50481                                         aflatoxins
# 50482                  salmonella enterica ser. mbandaka
# 50483                        unauthorised colour sudan 1
# 50484                     salmonella enterica ser. agona
# 50485  fenvalerate,unauthorised substance fenpropathr...
# 50486                            vibrio parahaemolyticus
# 50487                                       arsenic,lead
# 50488           too high content of e 210 - benzoic acid
# 50489                        unauthorised colour sudan 1
# 50490                        unauthorised colour sudan 1
# 50491  prohibited substance nitrofuran (metabolite) n...
# 50492                            bse tests not conducted
# 50493                        unauthorised colour sudan 1
# 50494                                         salmonella
# 50495                                           spoilage
# 50496             salmonella,too high count of coliforms
# 50497                          streptomycin unauthorised
# 50498               salmonella enterica ser. enteritidis
# 50499                                            cadmium
# 50500                              unauthorised operator
# 50501                e 452 - polyphosphates unauthorised
# 50502                                         salmonella
# 50503                                            dioxins
# 50504            too high content of e 200 - sorbic acid
# 50505                             listeria monocytogenes
# 50550           too high content of e 210 - benzoic acid
# 50551                e 452 - polyphosphates unauthorised
# 50552                                incorrect labelling
# 50553                   salmonella enterica ser. baguida
# 50554                                          histamine
#
#                                              HAZARDS_CAT      COUNT_ORIGEN  \
# 0                             pathogenic micro-organisms           Romania
# 1                                 natural toxins (other)           Germany
# 2                         food additives and flavourings           Croatia
# 3                                                 metals             Italy
# 4                                             mycotoxins            Turkey
# 5                             pathogenic micro-organisms           Ukraine
# 6      pathogenic micro-organisms,pathogenic micro-or...            France
# 7                                                 metals           Vietnam
# 8                                             mycotoxins     United States
# 9                                     pesticide residues            Turkey
# 10                            pathogenic micro-organisms           Estonia
# 11                            pathogenic micro-organisms            Poland
# 12                              environmental pollutants             China
# 13                              environmental pollutants           Germany
# 14                            pathogenic micro-organisms           Germany
# 15                        microbial contaminants (other)             Italy
# 16                                natural toxins (other)    Czech Republic
# 17                                                metals       Netherlands
# 18                 labelling absent/incomplete/incorrect           Belgium
# 19                        microbial contaminants (other)            Poland
# 20                        microbial contaminants (other)             Spain
# 21                                           composition          Thailand
# 22     labelling absent/incomplete/incorrect,composition           Romania
# 23                                            mycotoxins             China
# 24                                            mycotoxins    United Kingdom
# 25                                            mycotoxins             India
# 26                                  adulteration / fraud             China
# 27                               industrial contaminants             China
# 28                        food additives and flavourings       Philippines
# 29                                            novel food           Germany
# ...                                                  ...               ...
# 50481                                         mycotoxins              Iran
# 50482                         pathogenic micro-organisms       Netherlands
# 50483                                        composition             Spain
# 50484                         pathogenic micro-organisms    Belgium,France
# 50485  pesticide residues,pesticide residues,pesticid...            Taiwan
# 50486                         pathogenic micro-organisms          Malaysia
# 50487                                      metals,metals            Turkey
# 50488                     food additives and flavourings           Ecuador
# 50489                                        composition             Italy
# 50490                                        composition             Italy
# 50491          residues of veterinary medicinal products             India
# 50492                                               tses           Germany
# 50493                                        composition             Italy
# 50494                         pathogenic micro-organisms           Vietnam
# 50495                               organoleptic aspects             India
# 50496  pathogenic micro-organisms,microbial contamina...        Bangladesh
# 50497          residues of veterinary medicinal products            Mexico
# 50498                         pathogenic micro-organisms  Denmark,Thailand
# 50499                                             metals         Singapore
# 50500                      poor or insufficient controls            Russia
# 50501                     food additives and flavourings            France
# 50502                         pathogenic micro-organisms            France
# 50503                           environmental pollutants            Brazil
# 50504                     food additives and flavourings           Tunisia
# 50505                     microbial contaminants (other)    Austria,France
# 50550                     food additives and flavourings              Peru
# 50551                     food additives and flavourings            France
# 50552              labelling absent/incomplete/incorrect             China
# 50553                         pathogenic micro-organisms            Brazil
# 50554                    biological contaminants (other)         Indonesia
#
#                                             COUNT_DESTIN  \
# 0                                                 France
# 1                                                Denmark
# 2                                                 Poland
# 3                                          Andorra,Spain
# 4
# 5
# 6                                                Denmark
# 7
# 8
# 9
# 10                                               Finland
# 11                                       Poland,Slovakia
# 12                                           Netherlands
# 13                                           Netherlands
# 14                                               Finland
# 15                                           Italy,Spain
# 16                                        Sweden,Denmark
# 17
# 18                                               Denmark
# 19                                               Ukraine
# 20                                   Belgium,Netherlands
# 21                                        Denmark,Sweden
# 22                                                 Italy
# 23
# 24                                           Netherlands
# 25                                           Netherlands
# 26
# 27                                                Norway
# 28
# 29                                Austria,France,Germany
# ...                                                  ...
# 50481
# 50482                                             Sweden
# 50483  Austria,Colombia,Dominican Republic,Italy,Malt...
# 50484                                     Finland,Guinea
# 50485
# 50486
# 50487
# 50488
# 50489                                            Germany
# 50490   Czech Republic,Germany,Luxembourg,United Kingdom
# 50491  Austria,Belgium,Denmark,Germany,Latvia,Russia,...
# 50492                                            Germany
# 50493                Austria,Germany,Italy,United States
# 50494
# 50495
# 50496
# 50497
# 50498                                     Finland,Sweden
# 50499
# 50500
# 50501                                              Italy
# 50502                                              Italy
# 50503                                            Germany
# 50504
# 50505                                             France
# 50550
# 50551                                              Italy
# 50552
# 50553
# 50554                                            Belgium
#
#                 COUNT_CONCERN
# 0                     Belgium
# 1
# 2
# 3                     INFOSAN
# 4                      France
# 5                      Poland
# 6
# 7                 Netherlands
# 8                     Germany
# 9        Bulgaria,Netherlands
# 10
# 11
# 12             France,INFOSAN
# 13
# 14
# 15
# 16
# 17                    Belgium
# 18
# 19                    INFOSAN
# 20
# 21        INFOSAN,Netherlands
# 22
# 23             United Kingdom
# 24        Commission Services
# 25     INFOSAN,United Kingdom
# 26                     Poland
# 27
# 28                      Italy
# 29
# ...                       ...
# 50481                   Italy
# 50482
# 50483
# 50484
# 50485                   Spain
# 50486             Italy,Spain
# 50487                   Spain
# 50488                   Spain
# 50489
# 50490
# 50491                   Spain
# 50492
# 50493
# 50494             Italy,Spain
# 50495                 Germany
# 50496            France,Spain
# 50497    Spain,United Kingdom
# 50498
# 50499             Italy,Spain
# 50500                 Germany
# 50501
# 50502
# 50503
# 50504             Italy,Spain
# 50505
# 50550                   Spain
# 50551
# 50552             Italy,Spain
# 50553          Portugal,Spain
# 50554       Netherlands,Spain
#
# [50271 rows x 17 columns]

# %%
mask = (df['DATE_CASE'] >= '2004-01-01') & (df['DATE_CASE'] <= '2018-12-31')
df = df.loc[mask]

# %%
df['DATE_CASE'] =pd.to_datetime(df.DATE_CASE)
df['DATE_CASE'] = df.DATE_CASE.dt.month

# %%
features = [0,1,6,8]
target = [2]
X = df.iloc[:,features]
y = df.iloc[:,target]

# %%
X
# Out:
#         DATE_CASE     NOT_COUNTRY                       DISTRIBUTION_STAT  \
# 9800           12     Netherlands  distribution to other member countries
# 9801           12     Netherlands  distribution to other member countries
# 9802           12     Netherlands  distribution to other member countries
# 9803           12     Netherlands  distribution to other member countries
# 9804           12     Netherlands  distribution to other member countries
# 9805           12     Netherlands  distribution to other member countries
# 9806           12     Netherlands  distribution to other member countries
# 9807           12     Netherlands  distribution to other member countries
# 9808           12     Netherlands  product not (yet) placed on the market
# 9809           12  United Kingdom  distribution to other member countries
# 9810           12         Germany  product not (yet) placed on the market
# 9811           12          Poland  distribution to other member countries
# 9812           12          Poland  distribution to other member countries
# 9813           12          Poland  distribution to other member countries
# 9814           12          Poland  distribution to other member countries
# 9815           12          Poland  distribution to other member countries
# 9816           12          Poland  distribution to other member countries
# 9817           12          Poland  distribution to other member countries
# 9818           12          Poland  distribution to other member countries
# 9819           12          Poland  distribution to other member countries
# 9820           12          Poland  distribution to other member countries
# 9821           12          Poland  distribution to other member countries
# 9822           12          Poland  distribution to other member countries
# 9823           12          Greece  product not (yet) placed on the market
# 9824           12         Germany  distribution to other member countries
# 9825           12         Germany  distribution to other member countries
# 9826           12         Germany  distribution to other member countries
# 9827           12         Germany  distribution to other member countries
# 9828           12         Germany  distribution to other member countries
# 9829           12         Germany  distribution to other member countries
# ...           ...             ...                                     ...
# 141499          1           Italy
# 141500          1         Germany
# 141501          1          France
# 141502          1          France
# 141503          1          France
# 141504          1          France
# 141505          1  United Kingdom
# 141506          1  United Kingdom
# 141507          1         Finland
# 141508          1         Finland
# 141509          1         Finland
# 141510          1         Finland
# 141511          1           Spain
# 141512          1           Spain
# 141513          1         Germany
# 141514          1           Italy
# 141515          1           Italy
# 141516          1         Germany
# 141517          1           Italy
# 141518          1           Italy
# 141519          1          France
# 141520          1          France
# 141521          1           Spain
# 141522          1           Italy
# 141523          1           Italy
# 141524          1           Italy
# 141525          1        Portugal
# 141526          1        Portugal
# 141527          1     Netherlands
# 141528          1     Netherlands
#
#           COUNT_ORIGEN
# 9800             China
# 9801             China
# 9802             China
# 9803             China
# 9804             China
# 9805             China
# 9806             China
# 9807             China
# 9808         Argentina
# 9809    United Kingdom
# 9810           Nigeria
# 9811             China
# 9812             China
# 9813             China
# 9814             China
# 9815             China
# 9816             China
# 9817             China
# 9818             China
# 9819             China
# 9820             China
# 9821             China
# 9822             China
# 9823             Sudan
# 9824       South Korea
# 9825       South Korea
# 9826           Germany
# 9827           Germany
# 9828       Switzerland
# 9829       Switzerland
# ...                ...
# 141499         Vietnam
# 141500           India
# 141501      Bangladesh
# 141502      Bangladesh
# 141503      Bangladesh
# 141504      Bangladesh
# 141505          Mexico
# 141506          Mexico
# 141507         Denmark
# 141508         Denmark
# 141509        Thailand
# 141510        Thailand
# 141511       Singapore
# 141512       Singapore
# 141513          Russia
# 141514          France
# 141515          France
# 141516          Brazil
# 141517         Tunisia
# 141518         Tunisia
# 141519         Austria
# 141520          France
# 141521            Peru
# 141522          France
# 141523           China
# 141524           China
# 141525          Brazil
# 141526          Brazil
# 141527       Indonesia
# 141528       Indonesia
#
# [131694 rows x 4 columns]

# %%
y
# Out:
#                                                  PROD_CAT
# 9800                               food contact materials
# 9801                               food contact materials
# 9802                               food contact materials
# 9803                               food contact materials
# 9804                               food contact materials
# 9805                               food contact materials
# 9806                               food contact materials
# 9807                               food contact materials
# 9808                         nuts, nut products and seeds
# 9809          meat and meat products (other than poultry)
# 9810                         nuts, nut products and seeds
# 9811                               food contact materials
# 9812                               food contact materials
# 9813                               food contact materials
# 9814                               food contact materials
# 9815                               food contact materials
# 9816                               food contact materials
# 9817                               food contact materials
# 9818                               food contact materials
# 9819                               food contact materials
# 9820                               food contact materials
# 9821                               food contact materials
# 9822                               food contact materials
# 9823                         nuts, nut products and seeds
# 9824                                fruits and vegetables
# 9825                                fruits and vegetables
# 9826    dietetic foods, food supplements, fortified foods
# 9827    dietetic foods, food supplements, fortified foods
# 9828    dietetic foods, food supplements, fortified foods
# 9829    dietetic foods, food supplements, fortified foods
# ...                                                   ...
# 141499                             fish and fish products
# 141500                   crustaceans and products thereof
# 141501                   crustaceans and products thereof
# 141502                   crustaceans and products thereof
# 141503                   crustaceans and products thereof
# 141504                   crustaceans and products thereof
# 141505                              honey and royal jelly
# 141506                              honey and royal jelly
# 141507             poultry meat and poultry meat products
# 141508             poultry meat and poultry meat products
# 141509             poultry meat and poultry meat products
# 141510             poultry meat and poultry meat products
# 141511                             fish and fish products
# 141512                             fish and fish products
# 141513                                  ices and desserts
# 141514                             fish and fish products
# 141515        meat and meat products (other than poultry)
# 141516                      animal nutrition - (obsolete)
# 141517                        cereals and bakery products
# 141518                        cereals and bakery products
# 141519        meat and meat products (other than poultry)
# 141520        meat and meat products (other than poultry)
# 141521                            non-alcoholic beverages
# 141522                             fish and fish products
# 141523                              fruits and vegetables
# 141524                              fruits and vegetables
# 141525         molluscs and products thereof - (obsolete)
# 141526         molluscs and products thereof - (obsolete)
# 141527                             fish and fish products
# 141528                             fish and fish products
#
# [131694 rows x 1 columns]

# %%
enc = OneHotEncoder(handle_unknown='ignore', sparse = False)
enc.fit(X.values)
X_one_hot = enc.transform(X.values)

# %% [markdown]
# # Datos de test

# %%
data = pd.read_csv('C:/Users/Ceiec04/Desktop/Prediccion_Alertas_Alimentarias/Datasets/splited_2019_RASFF_DATA_16092019.csv', sep=';', 
                   header=0, index_col = 0)
test = data
test
# Out:
#        DATE_CASE  NOT_COUNTRY  \
# 0     2019-09-13       France
# 1     2019-09-13      Denmark
# 2     2019-09-13       Poland
# 3     2019-09-13        Spain
# 4     2019-09-13        Spain
# 5     2019-09-13       France
# 6     2019-09-13       Poland
# 7     2019-09-13      Denmark
# 8     2019-09-13      Denmark
# 9     2019-09-13  Netherlands
# 10    2019-09-12      Germany
# 11    2019-09-12     Bulgaria
# 12    2019-09-12     Bulgaria
# 13    2019-09-12      Finland
# 14    2019-09-12       Poland
# 15    2019-09-12       Poland
# 16    2019-09-12  Netherlands
# 17    2019-09-12  Netherlands
# 18    2019-09-12  Netherlands
# 19    2019-09-12      Finland
# 20    2019-09-12        Italy
# 21    2019-09-12        Italy
# 22    2019-09-11      Denmark
# 23    2019-09-11      Denmark
# 24    2019-09-11      Belgium
# 25    2019-09-11      Belgium
# 26    2019-09-11       Poland
# 27    2019-09-11  Netherlands
# 28    2019-09-11  Netherlands
# 29    2019-09-10       Sweden
# ...          ...          ...
# 9805  2019-01-04      Belgium
# 9806  2019-01-04       Greece
# 9807  2019-01-04      Belgium
# 9808  2019-01-04        Italy
# 9809  2019-01-04     Bulgaria
# 9810  2019-01-03       France
# 9811  2019-01-03       France
# 9812  2019-01-03       France
# 9813  2019-01-03       France
# 9814  2019-01-03       France
# 9815  2019-01-03       France
# 9816  2019-01-03       France
# 9817  2019-01-03      Denmark
# 9818  2019-01-03      Denmark
# 9819  2019-01-03       Latvia
# 9820  2019-01-03       Greece
# 9821  2019-01-03       Greece
# 9822  2019-01-03     Bulgaria
# 9823  2019-01-03        Spain
# 9824  2019-01-03       Poland
# 9825  2019-01-03        Spain
# 9826  2019-01-03       Sweden
# 9827  2019-01-02    Lithuania
# 9828  2019-01-02    Lithuania
# 9829  2019-01-02      Finland
# 9830  2019-01-02      Finland
# 9831  2019-01-02    Lithuania
# 9832  2019-01-02      Germany
# 9833  2019-01-02      Germany
# 9834  2019-01-02      Germany
#
#                                                PROD_CAT  TYPE RISK_DECISION  \
# 0           meat and meat products (other than poultry)  food       serious
# 1          cocoa and cocoa preparations, coffee and tea  food       serious
# 2                                         confectionery  food       serious
# 3                           cereals and bakery products  food       serious
# 4                           cereals and bakery products  food       serious
# 5                                 fruits and vegetables  food       serious
# 6                                        feed materials  feed   not serious
# 7                 bivalve molluscs and products thereof  food       serious
# 8                 bivalve molluscs and products thereof  food       serious
# 9                                fish and fish products  food       serious
# 10                                       feed materials  feed       serious
# 11                                fruits and vegetables  food       serious
# 12                                fruits and vegetables  food       serious
# 13                                       feed materials  feed   not serious
# 14               poultry meat and poultry meat products  food   not serious
# 15               poultry meat and poultry meat products  food   not serious
# 16    dietetic foods, food supplements, fortified foods  food       serious
# 17    dietetic foods, food supplements, fortified foods  food       serious
# 18                                       feed materials  feed     undecided
# 19                                       feed materials  feed   not serious
# 20                bivalve molluscs and products thereof  food       serious
# 21                bivalve molluscs and products thereof  food       serious
# 22         cocoa and cocoa preparations, coffee and tea  food       serious
# 23         cocoa and cocoa preparations, coffee and tea  food       serious
# 24    dietetic foods, food supplements, fortified foods  food       serious
# 25                           prepared dishes and snacks  food       serious
# 26                               milk and milk products  food       serious
# 27                                fruits and vegetables  food       serious
# 28                                fruits and vegetables  food       serious
# 29         cocoa and cocoa preparations, coffee and tea  food       serious
# ...                                                 ...   ...           ...
# 9805                             fish and fish products  food       serious
# 9806                       nuts, nut products and seeds  food       serious
# 9807             poultry meat and poultry meat products  food       serious
# 9808                             food contact materials   fcm     undecided
# 9809                              fruits and vegetables  food       serious
# 9810                              fruits and vegetables  food       serious
# 9811                              fruits and vegetables  food       serious
# 9812                              fruits and vegetables  food       serious
# 9813                              fruits and vegetables  food       serious
# 9814                              fruits and vegetables  food       serious
# 9815                              fruits and vegetables  food       serious
# 9816                              fruits and vegetables  food       serious
# 9817                       nuts, nut products and seeds  food   not serious
# 9818                       nuts, nut products and seeds  food   not serious
# 9819  dietetic foods, food supplements, fortified foods  food   not serious
# 9820                       nuts, nut products and seeds  food       serious
# 9821                       nuts, nut products and seeds  food       serious
# 9822                              fruits and vegetables  food       serious
# 9823                   crustaceans and products thereof  food   not serious
# 9824                              fruits and vegetables  food       serious
# 9825                             fish and fish products  food   not serious
# 9826                              fruits and vegetables  food       serious
# 9827  dietetic foods, food supplements, fortified foods  food   not serious
# 9828  dietetic foods, food supplements, fortified foods  food   not serious
# 9829                       nuts, nut products and seeds  food       serious
# 9830                       nuts, nut products and seeds  food       serious
# 9831                             food contact materials   fcm   not serious
# 9832                              fruits and vegetables  food   not serious
# 9833                              fruits and vegetables  food   not serious
# 9834                                           pet food  feed   not serious
#
#                       ACTION_TAKEN  \
# 0                    no stock left
# 1            recall from consumers
# 2            informing authorities
# 3       withdrawal from the market
# 4       withdrawal from the market
# 5                      re-dispatch
# 6           informing recipient(s)
# 7     withdrawal from recipient(s)
# 8     withdrawal from recipient(s)
# 9            import not authorised
# 10                     re-dispatch
# 11                     destruction
# 12                     destruction
# 13     physical/chemical treatment
# 14          informing recipient(s)
# 15          informing recipient(s)
# 16             informing consignor
# 17             informing consignor
# 18                     destruction
# 19     physical/chemical treatment
# 20      withdrawal from the market
# 21      withdrawal from the market
# 22           recall from consumers
# 23           recall from consumers
# 24           recall from consumers
# 25           recall from consumers
# 26      withdrawal from the market
# 27          informing recipient(s)
# 28          informing recipient(s)
# 29
# ...                            ...
# 9805        informing recipient(s)
# 9806         import not authorised
# 9807                   destruction
# 9808    placed under customs seals
# 9809    placed under customs seals
# 9810         recall from consumers
# 9811         recall from consumers
# 9812         recall from consumers
# 9813         recall from consumers
# 9814         recall from consumers
# 9815         recall from consumers
# 9816         recall from consumers
# 9817    withdrawal from the market
# 9818    withdrawal from the market
# 9819         import not authorised
# 9820         import not authorised
# 9821         import not authorised
# 9822    placed under customs seals
# 9823
# 9824                   re-dispatch
# 9825
# 9826    withdrawal from the market
# 9827                 no stock left
# 9828                 no stock left
# 9829         recall from consumers
# 9830         recall from consumers
# 9831  withdrawal from recipient(s)
# 9832                   re-dispatch
# 9833                   re-dispatch
# 9834
#
#                                       DISTRIBUTION_STAT  \
# 0                no distribution from notifying country
# 1                no distribution from notifying country
# 2          distribution restricted to notifying country
# 3                  distribution to non-member countries
# 4                  distribution to non-member countries
# 5                product not (yet) placed on the market
# 6                product not (yet) placed on the market
# 7          product (presumably) no longer on the market
# 8          product (presumably) no longer on the market
# 9                product not (yet) placed on the market
# 10               product not (yet) placed on the market
# 11               product not (yet) placed on the market
# 12               product not (yet) placed on the market
# 13               no distribution from notifying country
# 14         product (presumably) no longer on the market
# 15         product (presumably) no longer on the market
# 16               no distribution from notifying country
# 17               no distribution from notifying country
# 18               no distribution from notifying country
# 19               no distribution from notifying country
# 20               distribution to other member countries
# 21               distribution to other member countries
# 22               distribution to other member countries
# 23               distribution to other member countries
# 24                                product traded online
# 25               distribution to other member countries
# 26                 distribution to non-member countries
# 27               no distribution from notifying country
# 28               no distribution from notifying country
# 29               distribution to other member countries
# ...                                                 ...
# 9805       product (presumably) no longer on the market
# 9806             product not (yet) placed on the market
# 9807       product (presumably) no longer on the market
# 9808  product allowed to travel to destination under...
# 9809             product not (yet) placed on the market
# 9810             distribution to other member countries
# 9811             distribution to other member countries
# 9812             distribution to other member countries
# 9813             distribution to other member countries
# 9814             distribution to other member countries
# 9815             distribution to other member countries
# 9816             distribution to other member countries
# 9817             distribution to other member countries
# 9818             distribution to other member countries
# 9819             product not (yet) placed on the market
# 9820             product not (yet) placed on the market
# 9821             product not (yet) placed on the market
# 9822             product not (yet) placed on the market
# 9823             product not (yet) placed on the market
# 9824             product not (yet) placed on the market
# 9825             product not (yet) placed on the market
# 9826       distribution restricted to notifying country
# 9827       product (presumably) no longer on the market
# 9828       product (presumably) no longer on the market
# 9829             no distribution from notifying country
# 9830             no distribution from notifying country
# 9831             no distribution from notifying country
# 9832             product not (yet) placed on the market
# 9833             product not (yet) placed on the market
# 9834    information on distribution not (yet) available
#
#                                 HAZARDS_CAT    COUNT_ORIGEN COUNT_DESTIN  \
# 0                pathogenic micro-organisms         Romania       France
# 1                    natural toxins (other)         Germany      Denmark
# 2            food additives and flavourings         Croatia       Poland
# 3                                    metals           Italy      Andorra
# 4                                    metals           Italy        Spain
# 5                                mycotoxins          Turkey
# 6                pathogenic micro-organisms         Ukraine
# 7                pathogenic micro-organisms          France      Denmark
# 8                pathogenic micro-organisms          France      Denmark
# 9                                    metals         Vietnam
# 10                               mycotoxins   United States
# 11                       pesticide residues          Turkey
# 12                       pesticide residues          Turkey
# 13               pathogenic micro-organisms         Estonia      Finland
# 14               pathogenic micro-organisms          Poland       Poland
# 15               pathogenic micro-organisms          Poland     Slovakia
# 16                 environmental pollutants           China  Netherlands
# 17                 environmental pollutants           China  Netherlands
# 18                 environmental pollutants         Germany  Netherlands
# 19               pathogenic micro-organisms         Germany      Finland
# 20           microbial contaminants (other)           Italy        Italy
# 21           microbial contaminants (other)           Italy        Spain
# 22                   natural toxins (other)  Czech Republic       Sweden
# 23                   natural toxins (other)  Czech Republic      Denmark
# 24                                   metals     Netherlands
# 25    labelling absent/incomplete/incorrect         Belgium      Denmark
# 26           microbial contaminants (other)          Poland      Ukraine
# 27           microbial contaminants (other)           Spain      Belgium
# 28           microbial contaminants (other)           Spain  Netherlands
# 29                              composition        Thailand      Denmark
# ...                                     ...             ...          ...
# 9805        biological contaminants (other)          France  Switzerland
# 9806             pathogenic micro-organisms           Sudan
# 9807             pathogenic micro-organisms          Poland      Belgium
# 9808                                 metals           China
# 9809                     pesticide residues          Turkey
# 9810                     pesticide residues           China      Austria
# 9811                     pesticide residues           China       France
# 9812                     pesticide residues           China        Italy
# 9813                     pesticide residues           China  Netherlands
# 9814                     pesticide residues           China      Romania
# 9815                     pesticide residues           China        Spain
# 9816                     pesticide residues           China      Vietnam
# 9817                         foreign bodies         Denmark      Denmark
# 9818                         foreign bodies         Denmark      Iceland
# 9819                              radiation          Russia
# 9820             pathogenic micro-organisms           Sudan
# 9821             pathogenic micro-organisms           Sudan
# 9822                     pesticide residues          Turkey
# 9823          poor or insufficient controls   United States
# 9824                             mycotoxins          Turkey
# 9825          poor or insufficient controls   United States
# 9826                            composition         Lebanon       Sweden
# 9827                            composition          Poland
# 9828                            composition          Poland
# 9829                             mycotoxins         Denmark      Finland
# 9830                             mycotoxins  unknown origin      Finland
# 9831                   organoleptic aspects           China    Lithuania
# 9832         food additives and flavourings          Turkey
# 9833         food additives and flavourings          Turkey
# 9834         microbial contaminants (other)          Mexico
#
#      COUNT_CONCERN
# 0          Belgium
# 1
# 2
# 3          INFOSAN
# 4          INFOSAN
# 5           France
# 6           Poland
# 7
# 8
# 9      Netherlands
# 10         Germany
# 11        Bulgaria
# 12     Netherlands
# 13
# 14
# 15
# 16          France
# 17         INFOSAN
# 18
# 19
# 20
# 21
# 22
# 23
# 24         Belgium
# 25
# 26         INFOSAN
# 27
# 28
# 29         INFOSAN
# ...            ...
# 9805
# 9806        Greece
# 9807
# 9808         Italy
# 9809      Bulgaria
# 9810       INFOSAN
# 9811       INFOSAN
# 9812       INFOSAN
# 9813       INFOSAN
# 9814       INFOSAN
# 9815       INFOSAN
# 9816       INFOSAN
# 9817
# 9818
# 9819        Latvia
# 9820        Greece
# 9821        Greece
# 9822      Bulgaria
# 9823         Spain
# 9824        Poland
# 9825         Spain
# 9826       INFOSAN
# 9827     Lithuania
# 9828     Lithuania
# 9829
# 9830
# 9831       Denmark
# 9832       Germany
# 9833        Poland
# 9834       Germany
#
# [9835 rows x 11 columns]

# %%
test['DATE_CASE'] =pd.to_datetime(test.DATE_CASE)
test['DATE_CASE'] = test.DATE_CASE.dt.month

# %%
X_test = test.iloc[:,features]
y_test = test.iloc[:,target]

# %%
X_test_OHE = enc.transform(X_test.values)

# %% [markdown]
# # Decision tree

# %%
clf = tree.DecisionTreeClassifier(criterion='gini')
clf = clf.fit(X_one_hot,y)

# %%
y_pred = clf.predict(X_test_OHE)

# %%
print(classification_report(y_test,y_pred))
# Out:
#                                                    precision    recall  f1-score   support
#
#                               alcoholic beverages       0.00      0.00      0.00        24
#                     animal nutrition - (obsolete)       0.00      0.00      0.00         0
#             bivalve molluscs and products thereof       0.19      0.37      0.25       120
#                  cephalopods and products thereof       0.06      0.20      0.09        30
#                       cereals and bakery products       0.04      0.06      0.04       344
#      cocoa and cocoa preparations, coffee and tea       0.11      0.05      0.07       202
#                                    compound feeds       0.00      0.00      0.00        24
#                                     confectionery       0.05      0.04      0.05       221
#                  crustaceans and products thereof       0.07      0.10      0.08        42
# dietetic foods, food supplements, fortified foods       0.55      0.47      0.51      1117
#                             eggs and egg products       0.00      0.00      0.00        51
#                                     fats and oils       0.81      0.30      0.44       486
#                                    feed additives       0.00      0.00      0.00        35
#      feed for food-producing animals - (obsolete)       0.00      0.00      0.00         0
#                                    feed materials       0.09      0.16      0.11       327
#                                  feed premixtures       0.00      0.00      0.00         3
#                            fish and fish products       0.32      0.35      0.34       548
#                    food additives and flavourings       0.00      0.00      0.00        49
#                            food contact materials       0.63      0.48      0.54       600
#                             fruits and vegetables       0.34      0.49      0.40       997
#                                        gastropods       0.00      0.00      0.00         2
#                                  herbs and spices       0.17      0.06      0.08       798
#                             honey and royal jelly       0.00      0.00      0.00        11
#                                 ices and desserts       0.00      0.00      0.00       107
#       meat and meat products (other than poultry)       0.14      0.13      0.14       524
#                            milk and milk products       0.41      0.67      0.51       379
#        molluscs and products thereof - (obsolete)       0.00      0.00      0.00         0
#                             natural mineral water       0.00      0.00      0.00         4
#                           non-alcoholic beverages       0.01      0.02      0.01        55
#                      nuts, nut products and seeds       0.43      0.55      0.48       899
#                        other food product / mixed       0.07      0.07      0.07       233
#                                          pet food       0.50      0.03      0.05       806
#            poultry meat and poultry meat products       0.49      0.51      0.50       475
#                        prepared dishes and snacks       0.01      0.03      0.01       159
#              soups, broths, sauces and condiments       0.03      0.02      0.03       152
#               water for human consumption (other)       0.00      0.00      0.00         5
#                                              wine       0.00      0.00      0.00         6
#
#                                         micro avg       0.30      0.30      0.30      9835
#                                         macro avg       0.15      0.14      0.13      9835
#                                      weighted avg       0.35      0.30      0.29      9835
# C:\Users\Ceiec04\Anaconda3\envs\tensorflow-gpu\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Ceiec04\Anaconda3\envs\tensorflow-gpu\lib\site-packages\sklearn\metrics\classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
clf.score(X_test_OHE, y_test)
# Out:
# 0.2987290289781393

# %% [markdown]
# # Random forest

# %%
clf = RandomForestClassifier()
clf = clf.fit(X_one_hot,y)
# Out:
# C:\Users\Ceiec04\Anaconda3\envs\tensorflow-gpu\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Ceiec04\Anaconda3\envs\tensorflow-gpu\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
y_pred = clf.predict(X_test_OHE)

# %%
print(classification_report(y_test,y_pred))
# Out:
#                                                    precision    recall  f1-score   support
#
#                               alcoholic beverages       0.00      0.00      0.00        24
#                     animal nutrition - (obsolete)       0.00      0.00      0.00         0
#             bivalve molluscs and products thereof       0.17      0.30      0.22       120
#                  cephalopods and products thereof       0.06      0.17      0.09        30
#                       cereals and bakery products       0.07      0.07      0.07       344
#      cocoa and cocoa preparations, coffee and tea       0.04      0.02      0.03       202
#                                    compound feeds       0.00      0.00      0.00        24
#                                     confectionery       0.02      0.01      0.02       221
#                  crustaceans and products thereof       0.07      0.07      0.07        42
# dietetic foods, food supplements, fortified foods       0.35      0.51      0.42      1117
#                             eggs and egg products       0.00      0.00      0.00        51
#                                     fats and oils       0.95      0.29      0.45       486
#                                    feed additives       0.00      0.00      0.00        35
#      feed for food-producing animals - (obsolete)       0.00      0.00      0.00         0
#                                    feed materials       0.10      0.17      0.12       327
#                                  feed premixtures       0.00      0.00      0.00         3
#                            fish and fish products       0.32      0.40      0.35       548
#                    food additives and flavourings       0.58      0.92      0.71        49
#                            food contact materials       0.53      0.58      0.55       600
#                             fruits and vegetables       0.34      0.52      0.41       997
#                                        gastropods       0.00      0.00      0.00         2
#                                  herbs and spices       0.33      0.13      0.18       798
#                             honey and royal jelly       0.00      0.00      0.00        11
#                                 ices and desserts       0.00      0.00      0.00       107
#       meat and meat products (other than poultry)       0.21      0.18      0.20       524
#                            milk and milk products       0.43      0.67      0.52       379
#        molluscs and products thereof - (obsolete)       0.00      0.00      0.00         0
#                             natural mineral water       0.00      0.00      0.00         4
#                           non-alcoholic beverages       0.00      0.00      0.00        55
#                      nuts, nut products and seeds       0.49      0.56      0.52       899
#                        other food product / mixed       0.17      0.07      0.10       233
#                                          pet food       0.61      0.03      0.07       806
#            poultry meat and poultry meat products       0.41      0.55      0.47       475
#                        prepared dishes and snacks       0.00      0.00      0.00       159
#              soups, broths, sauces and condiments       0.03      0.02      0.02       152
#               water for human consumption (other)       0.00      0.00      0.00         5
#                                              wine       0.00      0.00      0.00         6
#
#                                         micro avg       0.33      0.33      0.33      9835
#                                         macro avg       0.17      0.17      0.15      9835
#                                      weighted avg       0.36      0.33      0.30      9835
# C:\Users\Ceiec04\Anaconda3\envs\tensorflow-gpu\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Ceiec04\Anaconda3\envs\tensorflow-gpu\lib\site-packages\sklearn\metrics\classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
clf.score(X_test_OHE, y_test)
# Out:
# 0.32963904422979157

# %% [markdown]
# # Regresión logística

# %%
clf = LogisticRegression()
clf = clf.fit(X_one_hot,y)

# %%
y_pred = clf.predict(X_test_OHE)

# %%
print(classification_report(y_test,y_pred))
# Out:
#                                                    precision    recall  f1-score   support
#
#                               alcoholic beverages       0.00      0.00      0.00        24
#             bivalve molluscs and products thereof       0.21      0.25      0.23       120
#                  cephalopods and products thereof       0.31      0.13      0.19        30
#                       cereals and bakery products       0.13      0.07      0.09       344
#      cocoa and cocoa preparations, coffee and tea       0.00      0.00      0.00       202
#                                    compound feeds       0.00      0.00      0.00        24
#                                     confectionery       0.00      0.00      0.00       221
#                  crustaceans and products thereof       0.02      0.02      0.02        42
# dietetic foods, food supplements, fortified foods       0.30      0.73      0.43      1117
#                             eggs and egg products       0.00      0.00      0.00        51
#                                     fats and oils       0.87      0.39      0.54       486
#                                    feed additives       0.01      0.03      0.02        35
#                                    feed materials       0.26      0.22      0.24       327
#                                  feed premixtures       0.00      0.00      0.00         3
#                            fish and fish products       0.32      0.51      0.40       548
#                    food additives and flavourings       0.00      0.00      0.00        49
#                            food contact materials       0.50      0.68      0.58       600
#                             fruits and vegetables       0.23      0.37      0.29       997
#                                        gastropods       0.00      0.00      0.00         2
#                                  herbs and spices       0.40      0.11      0.17       798
#                             honey and royal jelly       0.00      0.00      0.00        11
#                                 ices and desserts       0.00      0.00      0.00       107
#       meat and meat products (other than poultry)       0.29      0.17      0.21       524
#                            milk and milk products       0.46      0.75      0.57       379
#                             natural mineral water       0.00      0.00      0.00         4
#                           non-alcoholic beverages       0.00      0.00      0.00        55
#                      nuts, nut products and seeds       0.56      0.52      0.54       899
#                        other food product / mixed       0.18      0.07      0.10       233
#                                          pet food       0.00      0.00      0.00       806
#            poultry meat and poultry meat products       0.45      0.43      0.44       475
#                        prepared dishes and snacks       0.04      0.04      0.04       159
#              soups, broths, sauces and condiments       0.19      0.07      0.10       152
#               water for human consumption (other)       0.00      0.00      0.00         5
#                                              wine       0.00      0.00      0.00         6
#
#                                         micro avg       0.34      0.34      0.34      9835
#                                         macro avg       0.17      0.16      0.15      9835
#                                      weighted avg       0.31      0.34      0.30      9835
# C:\Users\Ceiec04\Anaconda3\envs\tensorflow-gpu\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
clf.score(X_test_OHE, y_test)
# Out:
# 0.34143365531265885

# %% [markdown]
# # MLP básico de sklearn

# %%
clf = MLPClassifier(hidden_layer_sizes=(100),max_iter=200)
clf = clf.fit(X_one_hot,y)
y_pred = clf.predict(X_test_OHE)
print(classification_report(y_test,y_pred))
clf.score(X_test_OHE, y_test)
# Out:
# C:\Users\Ceiec04\Anaconda3\envs\tensorflow-gpu\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:916: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#                                                    precision    recall  f1-score   support
#
#                               alcoholic beverages       0.00      0.00      0.00         7
#                   animal by-products - (obsolete)       0.00      0.00      0.00         0
#                     animal nutrition - (obsolete)       0.00      0.00      0.00         0
#             bivalve molluscs and products thereof       0.32      0.48      0.39        56
#                  cephalopods and products thereof       0.25      0.18      0.21        22
#                       cereals and bakery products       0.13      0.13      0.13       108
#      cocoa and cocoa preparations, coffee and tea       0.27      0.05      0.09        55
#                                    compound feeds       0.00      0.00      0.00         7
#                                     confectionery       0.13      0.04      0.06        48
#                  crustaceans and products thereof       0.08      0.09      0.09        33
# dietetic foods, food supplements, fortified foods       0.62      0.63      0.62       222
#                             eggs and egg products       0.00      0.00      0.00        20
#                                     fats and oils       0.29      0.17      0.21        24
#                                    feed additives       0.00      0.00      0.00         8
#      feed for food-producing animals - (obsolete)       0.00      0.00      0.00         0
#                                    feed materials       0.31      0.35      0.33       164
#                                  feed premixtures       0.00      0.00      0.00         2
#                            fish and fish products       0.47      0.48      0.48       211
#                    food additives and flavourings       0.00      0.00      0.00         3
#                            food contact materials       0.59      0.53      0.56       117
#                             fruits and vegetables       0.51      0.62      0.56       344
#                                        gastropods       0.00      0.00      0.00         1
#                                  herbs and spices       0.29      0.15      0.20       159
#                             honey and royal jelly       0.00      0.00      0.00         4
#                                 ices and desserts       0.00      0.00      0.00        11
#       meat and meat products (other than poultry)       0.23      0.28      0.25       169
#                            milk and milk products       0.30      0.33      0.31        55
#                             natural mineral water       0.00      0.00      0.00         4
#                           non-alcoholic beverages       0.14      0.05      0.07        20
#                      nuts, nut products and seeds       0.65      0.79      0.71       516
#                        other food product / mixed       0.17      0.04      0.07        47
#                                          pet food       0.22      0.10      0.13        42
#            poultry meat and poultry meat products       0.47      0.55      0.51       222
#                        prepared dishes and snacks       0.23      0.13      0.17        52
#              soups, broths, sauces and condiments       0.25      0.06      0.10        31
#               water for human consumption (other)       0.00      0.00      0.00         3
#                                              wine       0.00      0.00      0.00         2
#
#                                         micro avg       0.46      0.46      0.46      2789
#                                         macro avg       0.19      0.17      0.17      2789
#                                      weighted avg       0.42      0.46      0.43      2789
# C:\Users\Ceiec04\Anaconda3\envs\tensorflow-gpu\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\Users\Ceiec04\Anaconda3\envs\tensorflow-gpu\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Ceiec04\Anaconda3\envs\tensorflow-gpu\lib\site-packages\sklearn\metrics\classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# 0.45536034420939403
