# %%
import numpy as np
import pandas as pd
import numpy as np
from itertools import chain

# %% [markdown]
# # Creación de dataset con las alertas desacopladas

# %%
data = pd.read_csv('C:/Users/Ceiec04/Desktop/Prediccion_Alertas_Alimentarias/Datasets/full_RASFF_DATA_16092019.csv', sep=';', 
                   header=0, index_col = 0)
data = data.drop(columns=['NUMBER','CLASSIF','REF','SUBJET','PRODUCT','HAZARDS'])

# %%
def chainer(s):
    return list(chain.from_iterable(s.str.split(',')))

# %%
lens = data['HAZARDS_CAT'].str.split(',').map(len)
split1 = pd.DataFrame({'DATE_CASE': np.repeat(data['DATE_CASE'], lens),
                    'NOT_COUNTRY': np.repeat(data['NOT_COUNTRY'], lens),
                    'PROD_CAT': np.repeat(data['PROD_CAT'], lens),
                    'TYPE': np.repeat(data['TYPE'], lens),
                    'RISK_DECISION': np.repeat(data['RISK_DECISION'], lens),
                    'ACTION_TAKEN': np.repeat(data['ACTION_TAKEN'], lens),
                    'DISTRIBUTION_STAT': np.repeat(data['DISTRIBUTION_STAT'], lens),
                    'HAZARDS_CAT': chainer(data['HAZARDS_CAT']),                      #Columna que separo
                    'COUNT_ORIGEN': np.repeat(data['COUNT_ORIGEN'], lens),
                    'COUNT_DESTIN': np.repeat(data['COUNT_DESTIN'], lens),
                    'COUNT_CONCERN': np.repeat(data['COUNT_CONCERN'], lens)})

# %%
lens = split1['COUNT_ORIGEN'].str.split(',').map(len)
split2 = pd.DataFrame({'DATE_CASE': np.repeat(split1['DATE_CASE'], lens),
                    'NOT_COUNTRY': np.repeat(split1['NOT_COUNTRY'], lens),
                    'PROD_CAT': np.repeat(split1['PROD_CAT'], lens),
                    'TYPE': np.repeat(split1['TYPE'], lens),
                    'RISK_DECISION': np.repeat(split1['RISK_DECISION'], lens),
                    'ACTION_TAKEN': np.repeat(split1['ACTION_TAKEN'], lens),
                    'DISTRIBUTION_STAT': np.repeat(split1['DISTRIBUTION_STAT'], lens),
                    'HAZARDS_CAT': np.repeat(split1['HAZARDS_CAT'], lens),
                    'COUNT_ORIGEN': chainer(split1['COUNT_ORIGEN']),                #Columna que separo
                    'COUNT_DESTIN': np.repeat(split1['COUNT_DESTIN'], lens),
                    'COUNT_CONCERN': np.repeat(split1['COUNT_CONCERN'], lens)})

# %%
lens = split2['COUNT_DESTIN'].str.split(',').map(len)
split3 = pd.DataFrame({'DATE_CASE': np.repeat(split2['DATE_CASE'], lens),
                    'NOT_COUNTRY': np.repeat(split2['NOT_COUNTRY'], lens),
                    'PROD_CAT': np.repeat(split2['PROD_CAT'], lens),
                    'TYPE': np.repeat(split2['TYPE'], lens),
                    'RISK_DECISION': np.repeat(split2['RISK_DECISION'], lens),
                    'ACTION_TAKEN': np.repeat(split2['ACTION_TAKEN'], lens),
                    'DISTRIBUTION_STAT': np.repeat(split2['DISTRIBUTION_STAT'], lens),
                    'HAZARDS_CAT': np.repeat(split2['HAZARDS_CAT'], lens),
                    'COUNT_ORIGEN': np.repeat(split2['COUNT_ORIGEN'], lens),
                    'COUNT_DESTIN': chainer(split2['COUNT_DESTIN']),             #Columna que separo
                    'COUNT_CONCERN': np.repeat(split2['COUNT_CONCERN'], lens)})

# %%
lens = split3['COUNT_CONCERN'].str.split(',').map(len)
split4 = pd.DataFrame({'DATE_CASE': np.repeat(split3['DATE_CASE'], lens),
                    'NOT_COUNTRY': np.repeat(split3['NOT_COUNTRY'], lens),
                    'PROD_CAT': np.repeat(split3['PROD_CAT'], lens),
                    'TYPE': np.repeat(split3['TYPE'], lens),
                    'RISK_DECISION': np.repeat(split3['RISK_DECISION'], lens),
                    'ACTION_TAKEN': np.repeat(split3['ACTION_TAKEN'], lens),
                    'DISTRIBUTION_STAT': np.repeat(split3['DISTRIBUTION_STAT'], lens),
                    'HAZARDS_CAT': np.repeat(split3['HAZARDS_CAT'], lens),
                    'COUNT_ORIGEN': np.repeat(split3['COUNT_ORIGEN'], lens),
                    'COUNT_DESTIN': np.repeat(split3['COUNT_DESTIN'], lens),
                    'COUNT_CONCERN': chainer(split3['COUNT_CONCERN'])})        #Columna que separo

# %%
split4 = split4.reset_index(drop = True)
split4
# Out:
#          DATE_CASE          NOT_COUNTRY  \
# 0       13/09/2019               France
# 1       13/09/2019              Denmark
# 2       13/09/2019               Poland
# 3       13/09/2019                Spain
# 4       13/09/2019                Spain
# 5       13/09/2019               France
# 6       13/09/2019               Poland
# 7       13/09/2019              Denmark
# 8       13/09/2019              Denmark
# 9       13/09/2019          Netherlands
# 10      12/09/2019              Germany
# 11      12/09/2019             Bulgaria
# 12      12/09/2019             Bulgaria
# 13      12/09/2019              Finland
# 14      12/09/2019               Poland
# 15      12/09/2019               Poland
# 16      12/09/2019          Netherlands
# 17      12/09/2019          Netherlands
# 18      12/09/2019          Netherlands
# 19      12/09/2019              Finland
# 20      12/09/2019                Italy
# 21      12/09/2019                Italy
# 22      11/09/2019              Denmark
# 23      11/09/2019              Denmark
# 24      11/09/2019              Belgium
# 25      11/09/2019              Belgium
# 26      11/09/2019               Poland
# 27      11/09/2019          Netherlands
# 28      11/09/2019          Netherlands
# 29      10/09/2019               Sweden
# ...            ...                  ...
# 151384  28/02/1984              Germany
# 151385  09/02/1984          Netherlands
# 151386  25/01/1984       United Kingdom
# 151387  16/01/1984          Netherlands
# 151388  16/11/1983              Denmark
# 151389  14/09/1983               France
# 151390  11/04/1983              Belgium
# 151391  09/03/1983              Denmark
# 151392  08/02/1983               France
# 151393  27/01/1983              Denmark
# 151394  19/12/1982                Italy
# 151395  13/10/1982                Italy
# 151396  10/08/1982               France
# 151397  23/04/1982              Denmark
# 151398  05/02/1982               France
# 151399  10/12/1981              Belgium
# 151400  24/11/1981               France
# 151401  24/11/1981               France
# 151402  14/10/1981               France
# 151403  15/06/1981          Netherlands
# 151404  06/01/1981  Commission Services
# 151405  22/12/1980          Netherlands
# 151406  07/11/1980          Netherlands
# 151407  08/09/1980                Italy
# 151408  08/09/1980                Italy
# 151409  05/08/1980       United Kingdom
# 151410  20/06/1980               France
# 151411  30/04/1980               France
# 151412  10/04/1980              Belgium
# 151413  26/01/1980               France
#
#                                                  PROD_CAT  TYPE RISK_DECISION  \
# 0             meat and meat products (other than poultry)  food       serious
# 1            cocoa and cocoa preparations, coffee and tea  food       serious
# 2                                           confectionery  food       serious
# 3                             cereals and bakery products  food       serious
# 4                             cereals and bakery products  food       serious
# 5                                   fruits and vegetables  food       serious
# 6                                          feed materials  feed   not serious
# 7                   bivalve molluscs and products thereof  food       serious
# 8                   bivalve molluscs and products thereof  food       serious
# 9                                  fish and fish products  food       serious
# 10                                         feed materials  feed       serious
# 11                                  fruits and vegetables  food       serious
# 12                                  fruits and vegetables  food       serious
# 13                                         feed materials  feed   not serious
# 14                 poultry meat and poultry meat products  food   not serious
# 15                 poultry meat and poultry meat products  food   not serious
# 16      dietetic foods, food supplements, fortified foods  food       serious
# 17      dietetic foods, food supplements, fortified foods  food       serious
# 18                                         feed materials  feed     undecided
# 19                                         feed materials  feed   not serious
# 20                  bivalve molluscs and products thereof  food       serious
# 21                  bivalve molluscs and products thereof  food       serious
# 22           cocoa and cocoa preparations, coffee and tea  food       serious
# 23           cocoa and cocoa preparations, coffee and tea  food       serious
# 24      dietetic foods, food supplements, fortified foods  food       serious
# 25                             prepared dishes and snacks  food       serious
# 26                                 milk and milk products  food       serious
# 27                                  fruits and vegetables  food       serious
# 28                                  fruits and vegetables  food       serious
# 29           cocoa and cocoa preparations, coffee and tea  food       serious
# ...                                                   ...   ...           ...
# 151384                                      confectionery  food     undecided
# 151385                             food contact materials  food     undecided
# 151386                            non-alcoholic beverages  food     undecided
# 151387                   crustaceans and products thereof  food     undecided
# 151388                             milk and milk products  food     undecided
# 151389                                   herbs and spices  food     undecided
# 151390               soups, broths, sauces and condiments  food     undecided
# 151391                             fish and fish products  food     undecided
# 151392                                      confectionery  food     undecided
# 151393               soups, broths, sauces and condiments  food     undecided
# 151394                             food contact materials  food     undecided
# 151395                              fruits and vegetables  food     undecided
# 151396                   crustaceans and products thereof  food     undecided
# 151397                             fish and fish products  food     undecided
# 151398                             fish and fish products  food     undecided
# 151399                       nuts, nut products and seeds  food     undecided
# 151400        meat and meat products (other than poultry)  food     undecided
# 151401        meat and meat products (other than poultry)  food     undecided
# 151402                   crustaceans and products thereof  food     undecided
# 151403                              fruits and vegetables  food     undecided
# 151404                              fruits and vegetables  food     undecided
# 151405                             food contact materials  food     undecided
# 151406                   crustaceans and products thereof  food     undecided
# 151407                              fruits and vegetables  food     undecided
# 151408                              fruits and vegetables  food     undecided
# 151409        meat and meat products (other than poultry)  food     undecided
# 151410        meat and meat products (other than poultry)  food     undecided
# 151411        meat and meat products (other than poultry)  food     undecided
# 151412                   crustaceans and products thereof  food     undecided
# 151413                             fish and fish products  food     undecided
#
#                         ACTION_TAKEN  \
# 0                      no stock left
# 1              recall from consumers
# 2              informing authorities
# 3         withdrawal from the market
# 4         withdrawal from the market
# 5                        re-dispatch
# 6             informing recipient(s)
# 7       withdrawal from recipient(s)
# 8       withdrawal from recipient(s)
# 9              import not authorised
# 10                       re-dispatch
# 11                       destruction
# 12                       destruction
# 13       physical/chemical treatment
# 14            informing recipient(s)
# 15            informing recipient(s)
# 16               informing consignor
# 17               informing consignor
# 18                       destruction
# 19       physical/chemical treatment
# 20        withdrawal from the market
# 21        withdrawal from the market
# 22             recall from consumers
# 23             recall from consumers
# 24             recall from consumers
# 25             recall from consumers
# 26        withdrawal from the market
# 27            informing recipient(s)
# 28            informing recipient(s)
# 29
# ...                              ...
# 151384
# 151385
# 151386
# 151387
# 151388
# 151389
# 151390
# 151391
# 151392
# 151393
# 151394
# 151395
# 151396
# 151397
# 151398
# 151399
# 151400
# 151401
# 151402
# 151403
# 151404
# 151405
# 151406
# 151407
# 151408
# 151409
# 151410
# 151411
# 151412
# 151413
#
#                                    DISTRIBUTION_STAT  \
# 0             no distribution from notifying country
# 1             no distribution from notifying country
# 2       distribution restricted to notifying country
# 3               distribution to non-member countries
# 4               distribution to non-member countries
# 5             product not (yet) placed on the market
# 6             product not (yet) placed on the market
# 7       product (presumably) no longer on the market
# 8       product (presumably) no longer on the market
# 9             product not (yet) placed on the market
# 10            product not (yet) placed on the market
# 11            product not (yet) placed on the market
# 12            product not (yet) placed on the market
# 13            no distribution from notifying country
# 14      product (presumably) no longer on the market
# 15      product (presumably) no longer on the market
# 16            no distribution from notifying country
# 17            no distribution from notifying country
# 18            no distribution from notifying country
# 19            no distribution from notifying country
# 20            distribution to other member countries
# 21            distribution to other member countries
# 22            distribution to other member countries
# 23            distribution to other member countries
# 24                             product traded online
# 25            distribution to other member countries
# 26              distribution to non-member countries
# 27            no distribution from notifying country
# 28            no distribution from notifying country
# 29            distribution to other member countries
# ...                                              ...
# 151384
# 151385
# 151386
# 151387
# 151388
# 151389
# 151390
# 151391
# 151392
# 151393
# 151394
# 151395
# 151396
# 151397
# 151398
# 151399
# 151400
# 151401
# 151402
# 151403
# 151404
# 151405
# 151406
# 151407
# 151408
# 151409
# 151410
# 151411
# 151412
# 151413
#
#                                       HAZARDS_CAT    COUNT_ORIGEN  \
# 0                      pathogenic micro-organisms         Romania
# 1                          natural toxins (other)         Germany
# 2                  food additives and flavourings         Croatia
# 3                                          metals           Italy
# 4                                          metals           Italy
# 5                                      mycotoxins          Turkey
# 6                      pathogenic micro-organisms         Ukraine
# 7                      pathogenic micro-organisms          France
# 8                      pathogenic micro-organisms          France
# 9                                          metals         Vietnam
# 10                                     mycotoxins   United States
# 11                             pesticide residues          Turkey
# 12                             pesticide residues          Turkey
# 13                     pathogenic micro-organisms         Estonia
# 14                     pathogenic micro-organisms          Poland
# 15                     pathogenic micro-organisms          Poland
# 16                       environmental pollutants           China
# 17                       environmental pollutants           China
# 18                       environmental pollutants         Germany
# 19                     pathogenic micro-organisms         Germany
# 20                 microbial contaminants (other)           Italy
# 21                 microbial contaminants (other)           Italy
# 22                         natural toxins (other)  Czech Republic
# 23                         natural toxins (other)  Czech Republic
# 24                                         metals     Netherlands
# 25          labelling absent/incomplete/incorrect         Belgium
# 26                 microbial contaminants (other)          Poland
# 27                 microbial contaminants (other)           Spain
# 28                 microbial contaminants (other)           Spain
# 29                                    composition        Thailand
# ...                                           ...             ...
# 151384                                  allergens         Germany
# 151385                     not determined / other           China
# 151386                                composition  United Kingdom
# 151387                 pathogenic micro-organisms  unknown origin
# 151388             microbial contaminants (other)          France
# 151389                    industrial contaminants      Madagascar
# 151390                     natural toxins (other)         Belgium
# 151391                                     metals           Japan
# 151392             food additives and flavourings       Argentina
# 151393                 pathogenic micro-organisms         Germany
# 151394                                     metals           Italy
# 151395                     natural toxins (other)         Belgium
# 151396             microbial contaminants (other)        Malaysia
# 151397             microbial contaminants (other)          Canada
# 151398             microbial contaminants (other)        Thailand
# 151399                                 mycotoxins     Netherlands
# 151400                 pathogenic micro-organisms       Indonesia
# 151401             microbial contaminants (other)       Indonesia
# 151402                     natural toxins (other)            Cuba
# 151403                 pathogenic micro-organisms       Hong Kong
# 151404                         pesticide residues         Denmark
# 151405                     not determined / other     Netherlands
# 151406             microbial contaminants (other)        Pakistan
# 151407  residues of veterinary medicinal products          France
# 151408  residues of veterinary medicinal products         Romania
# 151409              poor or insufficient controls     Netherlands
# 151410             microbial contaminants (other)   United States
# 151411             microbial contaminants (other)         Belgium
# 151412             microbial contaminants (other)        Malaysia
# 151413                       organoleptic aspects    South Africa
#
#        COUNT_DESTIN        COUNT_CONCERN
# 0            France              Belgium
# 1           Denmark
# 2            Poland
# 3           Andorra              INFOSAN
# 4             Spain              INFOSAN
# 5                                 France
# 6                                 Poland
# 7           Denmark
# 8           Denmark
# 9                            Netherlands
# 10                               Germany
# 11                              Bulgaria
# 12                           Netherlands
# 13          Finland
# 14           Poland
# 15         Slovakia
# 16      Netherlands               France
# 17      Netherlands              INFOSAN
# 18      Netherlands
# 19          Finland
# 20            Italy
# 21            Spain
# 22           Sweden
# 23          Denmark
# 24                               Belgium
# 25          Denmark
# 26          Ukraine              INFOSAN
# 27          Belgium
# 28      Netherlands
# 29          Denmark              INFOSAN
# ...             ...                  ...
# 151384
# 151385                       Netherlands
# 151386
# 151387                       Netherlands
# 151388                           Denmark
# 151389                            France
# 151390
# 151391                           Denmark
# 151392                            France
# 151393                           Denmark
# 151394
# 151395                             Italy
# 151396                            France
# 151397                           Denmark
# 151398                            France
# 151399                           Belgium
# 151400                            France
# 151401                            France
# 151402                            France
# 151403                       Netherlands
# 151404               Commission Services
# 151405
# 151406                       Netherlands
# 151407                             Italy
# 151408                             Italy
# 151409                    United Kingdom
# 151410                            France
# 151411                            France
# 151412                           Belgium
# 151413                            France
#
# [151414 rows x 11 columns]

# %%
print(len(split4['NOT_COUNTRY'].unique()), len(data['NOT_COUNTRY'].unique()),len(split4['PROD_CAT'].unique()),len(data['PROD_CAT'].unique()),
     len(split4['TYPE'].unique()),len(data['TYPE'].unique()),len(split4['RISK_DECISION'].unique()),len(data['RISK_DECISION'].unique()),
     len(split4['ACTION_TAKEN'].unique()),len(data['ACTION_TAKEN'].unique()),len(split4['DISTRIBUTION_STAT'].unique()),
     len(data['DISTRIBUTION_STAT'].unique()),len(split4['HAZARDS_CAT'].unique()),
     len(data['HAZARDS_CAT'].unique()),len(split4['COUNT_ORIGEN'].unique()),len(data['COUNT_ORIGEN'].unique()),
     len(split4['COUNT_DESTIN'].unique()),len(data['COUNT_DESTIN'].unique()),
     len(split4['COUNT_CONCERN'].unique()),len(data['COUNT_CONCERN'].unique()))
# Out:
# 36 36 43 43 3 3 3 3 25 25 17 17 35 504 190 1398 215 4520 139 1308

# %%
split4.to_csv('splited_full_RASFF_DATA_16092019.csv', sep=';')

# %% [markdown]
# # Check del dataset

# %%
data = pd.read_csv('C:/Users/Ceiec04/Desktop/Prediccion_Alertas_Alimentarias/Datasets/splited_2019_RASFF_DATA_16092019.csv', sep=';', 
                   header=0, index_col = 0)')
data
# Out:
#        DATE_CASE  NOT_COUNTRY  \
# 0     2019-09-13       France
# 1     2019-09-13      Denmark
# 2     2019-09-13       Poland
# 3     2019-09-13        Spain
# 4     2019-09-13        Spain
# 5     2019-09-13       France
# 6     2019-09-13       Poland
# 7     2019-09-13      Denmark
# 8     2019-09-13      Denmark
# 9     2019-09-13  Netherlands
# 10    2019-09-12      Germany
# 11    2019-09-12     Bulgaria
# 12    2019-09-12     Bulgaria
# 13    2019-09-12      Finland
# 14    2019-09-12       Poland
# 15    2019-09-12       Poland
# 16    2019-09-12  Netherlands
# 17    2019-09-12  Netherlands
# 18    2019-09-12  Netherlands
# 19    2019-09-12      Finland
# 20    2019-09-12        Italy
# 21    2019-09-12        Italy
# 22    2019-09-11      Denmark
# 23    2019-09-11      Denmark
# 24    2019-09-11      Belgium
# 25    2019-09-11      Belgium
# 26    2019-09-11       Poland
# 27    2019-09-11  Netherlands
# 28    2019-09-11  Netherlands
# 29    2019-09-10       Sweden
# ...          ...          ...
# 9805  2019-01-04      Belgium
# 9806  2019-01-04       Greece
# 9807  2019-01-04      Belgium
# 9808  2019-01-04        Italy
# 9809  2019-01-04     Bulgaria
# 9810  2019-01-03       France
# 9811  2019-01-03       France
# 9812  2019-01-03       France
# 9813  2019-01-03       France
# 9814  2019-01-03       France
# 9815  2019-01-03       France
# 9816  2019-01-03       France
# 9817  2019-01-03      Denmark
# 9818  2019-01-03      Denmark
# 9819  2019-01-03       Latvia
# 9820  2019-01-03       Greece
# 9821  2019-01-03       Greece
# 9822  2019-01-03     Bulgaria
# 9823  2019-01-03        Spain
# 9824  2019-01-03       Poland
# 9825  2019-01-03        Spain
# 9826  2019-01-03       Sweden
# 9827  2019-01-02    Lithuania
# 9828  2019-01-02    Lithuania
# 9829  2019-01-02      Finland
# 9830  2019-01-02      Finland
# 9831  2019-01-02    Lithuania
# 9832  2019-01-02      Germany
# 9833  2019-01-02      Germany
# 9834  2019-01-02      Germany
#
#                                                PROD_CAT  TYPE RISK_DECISION  \
# 0           meat and meat products (other than poultry)  food       serious
# 1          cocoa and cocoa preparations, coffee and tea  food       serious
# 2                                         confectionery  food       serious
# 3                           cereals and bakery products  food       serious
# 4                           cereals and bakery products  food       serious
# 5                                 fruits and vegetables  food       serious
# 6                                        feed materials  feed   not serious
# 7                 bivalve molluscs and products thereof  food       serious
# 8                 bivalve molluscs and products thereof  food       serious
# 9                                fish and fish products  food       serious
# 10                                       feed materials  feed       serious
# 11                                fruits and vegetables  food       serious
# 12                                fruits and vegetables  food       serious
# 13                                       feed materials  feed   not serious
# 14               poultry meat and poultry meat products  food   not serious
# 15               poultry meat and poultry meat products  food   not serious
# 16    dietetic foods, food supplements, fortified foods  food       serious
# 17    dietetic foods, food supplements, fortified foods  food       serious
# 18                                       feed materials  feed     undecided
# 19                                       feed materials  feed   not serious
# 20                bivalve molluscs and products thereof  food       serious
# 21                bivalve molluscs and products thereof  food       serious
# 22         cocoa and cocoa preparations, coffee and tea  food       serious
# 23         cocoa and cocoa preparations, coffee and tea  food       serious
# 24    dietetic foods, food supplements, fortified foods  food       serious
# 25                           prepared dishes and snacks  food       serious
# 26                               milk and milk products  food       serious
# 27                                fruits and vegetables  food       serious
# 28                                fruits and vegetables  food       serious
# 29         cocoa and cocoa preparations, coffee and tea  food       serious
# ...                                                 ...   ...           ...
# 9805                             fish and fish products  food       serious
# 9806                       nuts, nut products and seeds  food       serious
# 9807             poultry meat and poultry meat products  food       serious
# 9808                             food contact materials   fcm     undecided
# 9809                              fruits and vegetables  food       serious
# 9810                              fruits and vegetables  food       serious
# 9811                              fruits and vegetables  food       serious
# 9812                              fruits and vegetables  food       serious
# 9813                              fruits and vegetables  food       serious
# 9814                              fruits and vegetables  food       serious
# 9815                              fruits and vegetables  food       serious
# 9816                              fruits and vegetables  food       serious
# 9817                       nuts, nut products and seeds  food   not serious
# 9818                       nuts, nut products and seeds  food   not serious
# 9819  dietetic foods, food supplements, fortified foods  food   not serious
# 9820                       nuts, nut products and seeds  food       serious
# 9821                       nuts, nut products and seeds  food       serious
# 9822                              fruits and vegetables  food       serious
# 9823                   crustaceans and products thereof  food   not serious
# 9824                              fruits and vegetables  food       serious
# 9825                             fish and fish products  food   not serious
# 9826                              fruits and vegetables  food       serious
# 9827  dietetic foods, food supplements, fortified foods  food   not serious
# 9828  dietetic foods, food supplements, fortified foods  food   not serious
# 9829                       nuts, nut products and seeds  food       serious
# 9830                       nuts, nut products and seeds  food       serious
# 9831                             food contact materials   fcm   not serious
# 9832                              fruits and vegetables  food   not serious
# 9833                              fruits and vegetables  food   not serious
# 9834                                           pet food  feed   not serious
#
#                       ACTION_TAKEN  \
# 0                    no stock left
# 1            recall from consumers
# 2            informing authorities
# 3       withdrawal from the market
# 4       withdrawal from the market
# 5                      re-dispatch
# 6           informing recipient(s)
# 7     withdrawal from recipient(s)
# 8     withdrawal from recipient(s)
# 9            import not authorised
# 10                     re-dispatch
# 11                     destruction
# 12                     destruction
# 13     physical/chemical treatment
# 14          informing recipient(s)
# 15          informing recipient(s)
# 16             informing consignor
# 17             informing consignor
# 18                     destruction
# 19     physical/chemical treatment
# 20      withdrawal from the market
# 21      withdrawal from the market
# 22           recall from consumers
# 23           recall from consumers
# 24           recall from consumers
# 25           recall from consumers
# 26      withdrawal from the market
# 27          informing recipient(s)
# 28          informing recipient(s)
# 29
# ...                            ...
# 9805        informing recipient(s)
# 9806         import not authorised
# 9807                   destruction
# 9808    placed under customs seals
# 9809    placed under customs seals
# 9810         recall from consumers
# 9811         recall from consumers
# 9812         recall from consumers
# 9813         recall from consumers
# 9814         recall from consumers
# 9815         recall from consumers
# 9816         recall from consumers
# 9817    withdrawal from the market
# 9818    withdrawal from the market
# 9819         import not authorised
# 9820         import not authorised
# 9821         import not authorised
# 9822    placed under customs seals
# 9823
# 9824                   re-dispatch
# 9825
# 9826    withdrawal from the market
# 9827                 no stock left
# 9828                 no stock left
# 9829         recall from consumers
# 9830         recall from consumers
# 9831  withdrawal from recipient(s)
# 9832                   re-dispatch
# 9833                   re-dispatch
# 9834
#
#                                       DISTRIBUTION_STAT  \
# 0                no distribution from notifying country
# 1                no distribution from notifying country
# 2          distribution restricted to notifying country
# 3                  distribution to non-member countries
# 4                  distribution to non-member countries
# 5                product not (yet) placed on the market
# 6                product not (yet) placed on the market
# 7          product (presumably) no longer on the market
# 8          product (presumably) no longer on the market
# 9                product not (yet) placed on the market
# 10               product not (yet) placed on the market
# 11               product not (yet) placed on the market
# 12               product not (yet) placed on the market
# 13               no distribution from notifying country
# 14         product (presumably) no longer on the market
# 15         product (presumably) no longer on the market
# 16               no distribution from notifying country
# 17               no distribution from notifying country
# 18               no distribution from notifying country
# 19               no distribution from notifying country
# 20               distribution to other member countries
# 21               distribution to other member countries
# 22               distribution to other member countries
# 23               distribution to other member countries
# 24                                product traded online
# 25               distribution to other member countries
# 26                 distribution to non-member countries
# 27               no distribution from notifying country
# 28               no distribution from notifying country
# 29               distribution to other member countries
# ...                                                 ...
# 9805       product (presumably) no longer on the market
# 9806             product not (yet) placed on the market
# 9807       product (presumably) no longer on the market
# 9808  product allowed to travel to destination under...
# 9809             product not (yet) placed on the market
# 9810             distribution to other member countries
# 9811             distribution to other member countries
# 9812             distribution to other member countries
# 9813             distribution to other member countries
# 9814             distribution to other member countries
# 9815             distribution to other member countries
# 9816             distribution to other member countries
# 9817             distribution to other member countries
# 9818             distribution to other member countries
# 9819             product not (yet) placed on the market
# 9820             product not (yet) placed on the market
# 9821             product not (yet) placed on the market
# 9822             product not (yet) placed on the market
# 9823             product not (yet) placed on the market
# 9824             product not (yet) placed on the market
# 9825             product not (yet) placed on the market
# 9826       distribution restricted to notifying country
# 9827       product (presumably) no longer on the market
# 9828       product (presumably) no longer on the market
# 9829             no distribution from notifying country
# 9830             no distribution from notifying country
# 9831             no distribution from notifying country
# 9832             product not (yet) placed on the market
# 9833             product not (yet) placed on the market
# 9834    information on distribution not (yet) available
#
#                                 HAZARDS_CAT    COUNT_ORIGEN COUNT_DESTIN  \
# 0                pathogenic micro-organisms         Romania       France
# 1                    natural toxins (other)         Germany      Denmark
# 2            food additives and flavourings         Croatia       Poland
# 3                                    metals           Italy      Andorra
# 4                                    metals           Italy        Spain
# 5                                mycotoxins          Turkey
# 6                pathogenic micro-organisms         Ukraine
# 7                pathogenic micro-organisms          France      Denmark
# 8                pathogenic micro-organisms          France      Denmark
# 9                                    metals         Vietnam
# 10                               mycotoxins   United States
# 11                       pesticide residues          Turkey
# 12                       pesticide residues          Turkey
# 13               pathogenic micro-organisms         Estonia      Finland
# 14               pathogenic micro-organisms          Poland       Poland
# 15               pathogenic micro-organisms          Poland     Slovakia
# 16                 environmental pollutants           China  Netherlands
# 17                 environmental pollutants           China  Netherlands
# 18                 environmental pollutants         Germany  Netherlands
# 19               pathogenic micro-organisms         Germany      Finland
# 20           microbial contaminants (other)           Italy        Italy
# 21           microbial contaminants (other)           Italy        Spain
# 22                   natural toxins (other)  Czech Republic       Sweden
# 23                   natural toxins (other)  Czech Republic      Denmark
# 24                                   metals     Netherlands
# 25    labelling absent/incomplete/incorrect         Belgium      Denmark
# 26           microbial contaminants (other)          Poland      Ukraine
# 27           microbial contaminants (other)           Spain      Belgium
# 28           microbial contaminants (other)           Spain  Netherlands
# 29                              composition        Thailand      Denmark
# ...                                     ...             ...          ...
# 9805        biological contaminants (other)          France  Switzerland
# 9806             pathogenic micro-organisms           Sudan
# 9807             pathogenic micro-organisms          Poland      Belgium
# 9808                                 metals           China
# 9809                     pesticide residues          Turkey
# 9810                     pesticide residues           China      Austria
# 9811                     pesticide residues           China       France
# 9812                     pesticide residues           China        Italy
# 9813                     pesticide residues           China  Netherlands
# 9814                     pesticide residues           China      Romania
# 9815                     pesticide residues           China        Spain
# 9816                     pesticide residues           China      Vietnam
# 9817                         foreign bodies         Denmark      Denmark
# 9818                         foreign bodies         Denmark      Iceland
# 9819                              radiation          Russia
# 9820             pathogenic micro-organisms           Sudan
# 9821             pathogenic micro-organisms           Sudan
# 9822                     pesticide residues          Turkey
# 9823          poor or insufficient controls   United States
# 9824                             mycotoxins          Turkey
# 9825          poor or insufficient controls   United States
# 9826                            composition         Lebanon       Sweden
# 9827                            composition          Poland
# 9828                            composition          Poland
# 9829                             mycotoxins         Denmark      Finland
# 9830                             mycotoxins  unknown origin      Finland
# 9831                   organoleptic aspects           China    Lithuania
# 9832         food additives and flavourings          Turkey
# 9833         food additives and flavourings          Turkey
# 9834         microbial contaminants (other)          Mexico
#
#      COUNT_CONCERN
# 0          Belgium
# 1
# 2
# 3          INFOSAN
# 4          INFOSAN
# 5           France
# 6           Poland
# 7
# 8
# 9      Netherlands
# 10         Germany
# 11        Bulgaria
# 12     Netherlands
# 13
# 14
# 15
# 16          France
# 17         INFOSAN
# 18
# 19
# 20
# 21
# 22
# 23
# 24         Belgium
# 25
# 26         INFOSAN
# 27
# 28
# 29         INFOSAN
# ...            ...
# 9805
# 9806        Greece
# 9807
# 9808         Italy
# 9809      Bulgaria
# 9810       INFOSAN
# 9811       INFOSAN
# 9812       INFOSAN
# 9813       INFOSAN
# 9814       INFOSAN
# 9815       INFOSAN
# 9816       INFOSAN
# 9817
# 9818
# 9819        Latvia
# 9820        Greece
# 9821        Greece
# 9822      Bulgaria
# 9823         Spain
# 9824        Poland
# 9825         Spain
# 9826       INFOSAN
# 9827     Lithuania
# 9828     Lithuania
# 9829
# 9830
# 9831       Denmark
# 9832       Germany
# 9833        Poland
# 9834       Germany
#
# [9835 rows x 11 columns]

# %%
print(data['HAZARDS_CAT'].unique())
len(data['HAZARDS_CAT'].unique())
# Out:
# ['pathogenic micro-organisms' 'natural toxins (other)'
#  'food additives and flavourings' 'metals' 'mycotoxins'
#  'pesticide residues' 'environmental pollutants'
#  'microbial contaminants (other)' 'labelling absent/incomplete/incorrect'
#  'composition' 'adulteration / fraud' 'industrial contaminants'
#  'novel food' 'parasitic infestation' 'poor or insufficient controls'
#  'foreign bodies' 'biological contaminants (other)' 'allergens'
#  'genetically modified food or feed' 'migration' 'tses'
#  'residues of veterinary medicinal products' 'organoleptic aspects'
#  'radiation' 'chemical contaminants (other)' 'not determined / other'
#  'packaging defective / incorrect' 'process contaminants' 'feed additives'
#  ' ']
# 30

# %%
print(data['COUNT_ORIGEN'].unique())
len(data['COUNT_ORIGEN'].unique())
# Out:
# ['Romania' 'Germany' 'Croatia' 'Italy' 'Turkey' 'Ukraine' 'France'
#  'Vietnam' 'United States' 'Estonia' 'Poland' 'China' 'Czech Republic'
#  'Netherlands' 'Belgium' 'Spain' 'Thailand' 'United Kingdom' 'India'
#  'Philippines' 'Canada' 'Brazil' 'unknown origin' 'Slovenia' 'Uruguay'
#  'New Zealand' 'Azerbaijan' 'Georgia' 'Uganda' 'Sudan' 'Egypt' 'Ecuador'
#  'Myanmar' 'Morocco' 'Mauritania' 'South Korea' 'Denmark' 'Taiwan'
#  'South Africa' 'Kenya' 'Slovakia' 'Argentina' 'Lebanon' 'Lithuania'
#  'Chile' 'Hong Kong' 'Nigeria' 'Panama' 'Latvia' 'Bolivia' 'Hungary'
#  'Pakistan' 'Dominican Republic' 'Austria' 'Grenada' 'El Salvador'
#  'Namibia' 'Greece' 'Belarus' 'Ireland' 'Iran' 'Portugal' 'Senegal' 'Peru'
#  'Tunisia' 'Bulgaria' 'Switzerland' 'Malaysia' 'Sweden' 'Albania'
#  'Suriname' 'Uzbekistan' 'Bangladesh' 'Israel' 'Jordan' 'Serbia'
#  'Ethiopia' 'Angola' 'Indonesia' 'Saudi Arabia' 'Russia' 'Ghana'
#  'Colombia' 'Norway' 'Mauritius' 'Luxembourg' 'Sri Lanka' 'Mexico'
#  'Republic of North Macedonia' 'Cyprus' ' ' 'Syria' 'Burkina Faso'
#  'Kosovo' 'Algeria' 'Guatemala' 'INFOSAN' 'Finland' 'Madagascar'
#  'Papua New Guinea' 'Moldova' 'Honduras' 'West Bank and Gaza Strip'
#  "Côte d'Ivoire" 'Togo' 'Niger' 'Liechtenstein' 'Kyrgyzstan' 'Japan'
#  'Barbados' 'Guinea' 'Costa Rica' 'Nicaragua' 'Maldives' 'Iceland'
#  'Paraguay' 'Chad' 'United Arab Emirates' 'Australia' 'Tanzania'
#  'Afghanistan' 'Oman' 'Belize' 'Cuba' 'Kazakhstan']
# 125

# %%
print(data['COUNT_DESTIN'].unique())
len(data['COUNT_DESTIN'].unique())
# Out:
# ['France' 'Denmark' 'Poland' 'Andorra' 'Spain' ' ' 'Finland' 'Slovakia'
#  'Netherlands' 'Italy' 'Sweden' 'Ukraine' 'Belgium' 'Norway' 'Austria'
#  'Germany' 'Slovenia' 'Croatia' 'Czech Republic' 'San Marino' 'Luxembourg'
#  'Antigua and Barbuda' 'Bahamas' 'Ghana' 'Guernsey' 'Jersey' 'Mauritius'
#  'United Arab Emirates' 'United Kingdom' 'Switzerland' 'Lithuania'
#  'Ireland' 'Hungary' 'Estonia' 'Latvia' 'Bahrain' 'Israel' 'Portugal'
#  'Romania' 'Kazakhstan' 'Russia' 'Greece' 'Canada' 'Monaco' 'Morocco'
#  'Vietnam' 'Bulgaria' 'Honduras' 'Iceland' 'Malta' 'Gibraltar' 'Hong Kong'
#  'INFOSAN' 'Isle of Man' 'Serbia' "Côte d'Ivoire" 'Bermuda'
#  'Cayman Islands' 'Malaysia' 'Philippines' 'Faeroe Islands' 'Albania'
#  'United States' 'Australia' 'Belarus' 'Congo' 'Gabon' 'Japan' 'Lebanon'
#  'Senegal' 'Seychelles' 'Togo' 'Cyprus' 'Algeria' 'China' 'Montenegro'
#  'South Korea' 'Taiwan' 'Kosovo' 'Kuwait' 'Qatar' 'Singapore'
#  'Democratic Republic of the Congo' 'South Africa' 'Angola'
#  'French Polynesia' 'Moldova' 'New Caledonia' 'Saint Pierre and Miquelon'
#  'Tunisia' 'India' 'Oman' 'Pakistan' 'Chile' 'Curaçao' 'Iraq' 'Suriname'
#  'Saint Helena' 'Thailand' 'New Zealand' 'Argentina' 'Turkey' 'Benin'
#  'Georgia' 'Bosnia and Herzegovina' 'Republic of North Macedonia' 'Peru'
#  'Indonesia' 'Maldives' 'Saint Barthélemy' 'Jordan' 'Libya' 'Brunei'
#  'Macao' 'Myanmar' 'Sint Maarten' 'Bolivia' 'Saudi Arabia' 'Cape Verde'
#  'Uganda' 'Uzbekistan' 'Dominican Republic' 'Falkland Islands' 'Haiti'
#  'Jamaica' 'Saint Kitts and Nevis' 'Saint Lucia' 'Saint Martin'
#  'Saint Vincent and the Grenadines' 'Mexico' 'Martinique']
# 131

# %%
print(data['COUNT_CONCERN'].unique())
len(data['COUNT_CONCERN'].unique())
# Out:
# ['Belgium' ' ' 'INFOSAN' 'France' 'Poland' 'Netherlands' 'Germany'
#  'Bulgaria' 'United Kingdom' 'Commission Services' 'Italy' 'Denmark'
#  'Greenland' 'Spain' 'Finland' 'Sweden' 'Hungary' 'Greece' 'Austria'
#  'Portugal' 'Switzerland' 'Latvia' 'Lithuania' 'Malta' 'Norway'
#  'United States' 'China' 'Czech Republic' 'Estonia' 'Slovakia' 'Croatia'
#  'Cyprus' 'Iran' 'New Zealand' 'United Arab Emirates' 'Turkey' 'Slovenia'
#  'European Food Safety Authority' 'unknown origin' 'Morocco' 'Hong Kong'
#  'Singapore' 'Pakistan' 'Iraq' 'Vietnam' 'Romania' 'Ukraine' 'Ireland'
#  'Lebanon' 'Bermuda' 'Luxembourg' 'Nigeria' 'Canada' 'Belarus' 'Taiwan'
#  'India' 'Ghana' 'Philippines' 'Thailand' 'South Korea' 'Andorra'
#  'Guernsey' 'Jersey' 'Sri Lanka' 'Monaco' 'Barbados' 'Malaysia' 'Jordan'
#  'Colombia' 'Uruguay' 'Albania' 'Bosnia and Herzegovina' 'Kosovo'
#  'Liechtenstein' 'Moldova' 'Montenegro' 'Republic of North Macedonia'
#  'Russia' 'Vatican City' 'Egypt' 'Bangladesh']
# 81

# %%
print(data['DISTRIBUTION_STAT'].unique())
len(data['DISTRIBUTION_STAT'].unique())
# Out:
# ['no distribution from notifying country'
#  'distribution restricted to notifying country'
#  'distribution to non-member countries'
#  'product not (yet) placed on the market'
#  'product (presumably) no longer on the market'
#  'distribution to other member countries' 'product traded online'
#  'information on distribution not (yet) available'
#  'product allowed to travel to destination under customs seals'
#  'no distribution to other member countries']
# 10
